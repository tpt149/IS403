# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import libraries

# %%
import os
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
plt.style.use('dark_background')

from pandas.core.arrays.sparse.array import ScalarIndexer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score

from keras.models import Sequential, load_model
from keras.layers import Dense, GRU
from keras.callbacks import ModelCheckpoint

# %%
# %cd /content/drive/MyDrive/IS403/Project/Data/
# Out:
# /content/drive/MyDrive/IS403/Project/Data

# %% [markdown]
# # Eval Function

# %%
def eval(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
def train_test_valid(data):
  train_size = int(0.7 * len(data))
  test_size = int(0.2 * len(data))
  val_size = len(data) - train_size - test_size

  train_data = data[:train_size]
  test_data = data[train_size:train_size+test_size]
  valid_data = data[train_size+test_size:]

  return train_data, test_data, valid_data, train_size, test_size, val_size

# %% [markdown]
# # AMAZON

# %% [markdown]
# ## Data

# %%
df_amz = pd.read_csv("AMZN.csv")
df_amz
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2017-12-01   58.602501   58.982498   57.599998   58.117500   58.117500
# 1     2017-12-04   58.692501   58.759998   56.400002   56.697498   56.697498
# 2     2017-12-05   56.412998   57.963501   56.237000   57.078499   57.078499
# 3     2017-12-06   56.899502   57.794498   56.804001   57.617500   57.617500
# 4     2017-12-07   57.829498   58.159500   57.549999   57.989498   57.989498
# ...          ...         ...         ...         ...         ...         ...
# 1384  2023-06-05  123.360001  125.800003  123.029999  125.300003  125.300003
# 1385  2023-06-06  125.070000  127.400002  125.000000  126.610001  126.610001
# 1386  2023-06-07  127.010002  127.370003  120.629997  121.230003  121.230003
# 1387  2023-06-08  123.010002  125.629997  122.260002  124.250000  124.250000
# 1388  2023-06-09  124.080002  125.800003  123.190002  123.430000  123.430000
#
#          Volume
# 0      82142000
# 1     118638000
# 2      81596000
# 3      57066000
# 4      50232000
# ...         ...
# 1384   47950100
# 1385   45695200
# 1386   95663300
# 1387   62159300
# 1388   51330000
#
# [1389 rows x 7 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Check null and na value

# %%
df_amz.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_amz.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Check datatype of each column

# %%
print("Date column data type: ", type(df_amz['Date'][0]))
print("Open column data type: ", type(df_amz['Open'][0]))
print("Close column data type: ", type(df_amz['Close'][0]))
print("High column data type: ", type(df_amz['High'][0]))
print("Low column data type: ", type(df_amz['Low'][0]))
print("Adj Close column data type: ", type(df_amz['Adj Close'][0]))
print("Volume column data type: ", type(df_amz['Low'][0]))
# Out:
# Date column data type:  <class 'str'>
# Open column data type:  <class 'numpy.float64'>
# Close column data type:  <class 'numpy.float64'>
# High column data type:  <class 'numpy.float64'>
# Low column data type:  <class 'numpy.float64'>
# Adj Close column data type:  <class 'numpy.float64'>
# Volume column data type:  <class 'numpy.float64'>

# %% [markdown]
# ### Convert date from string to date format & reset index

# %%
df_amz = df_amz.set_index(pd.DatetimeIndex(df_amz['Date'].values))

df_amz.index = pd.to_datetime(df_amz.index,format='%Y-%m-%d')

close_amz = pd.DataFrame(df_amz, columns=['Date', 'Close'])
close_amz.drop('Date', axis = 1, inplace = True)

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Get the duration of dataset

# %%
print("Starting date: ",df_amz.iloc[0][0])
print("Ending date: ", df_amz.iloc[-1][0])
# Out:
# Starting date:  2017-12-01
# Ending date:  2023-06-09

# %% [markdown]
# ### Visualize the per day closing price of the stock

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(close_amz['Close'])
plt.title('AMAZON closing price')
plt.show()

# %% [markdown]
# ## Train, test, valid

# %%
data_amz = close_amz.values
scaler = MinMaxScaler(feature_range=(0, 1))

sc_train = scaler.fit_transform(data_amz)

train_data, test_data, valid_data, train_size, test_size, val_size = train_test_valid(sc_train)

# %%
x_train, y_train = [], []

for i in range(100, len(train_data)):
    x_train.append(sc_train[i-100:i, 0])
    y_train.append(sc_train[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %% [markdown]
# ## Build & train model

# %%
model = Sequential()

model.add(GRU(50,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(GRU(50,return_sequences=True))
model.add(GRU(50))
model.add(Dense(1))

model.compile(loss='mean_absolute_error', optimizer='adam')

save_model = '/content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5'

best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.16380, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 10s - loss: 0.1638 - 10s/epoch - 568ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.16380 to 0.04056, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 4s - loss: 0.0406 - 4s/epoch - 195ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.04056 to 0.02602, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0260 - 3s/epoch - 152ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.02602 to 0.02235, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0224 - 3s/epoch - 193ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.02235 to 0.02180, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 6s - loss: 0.0218 - 6s/epoch - 348ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.02180 to 0.01985, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 6s - loss: 0.0199 - 6s/epoch - 334ms/step
# Epoch 7/80
#
# Epoch 7: loss did not improve from 0.01985
# 18/18 - 3s - loss: 0.0211 - 3s/epoch - 153ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.01985 to 0.01941, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 4s - loss: 0.0194 - 4s/epoch - 203ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.01941 to 0.01856, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 4s - loss: 0.0186 - 4s/epoch - 202ms/step
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.01856
# 18/18 - 3s - loss: 0.0198 - 3s/epoch - 148ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.01856 to 0.01730, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0173 - 3s/epoch - 155ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.01730 to 0.01714, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0171 - 3s/epoch - 155ms/step
# Epoch 13/80
#
# Epoch 13: loss improved from 0.01714 to 0.01664, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 5s - loss: 0.0166 - 5s/epoch - 254ms/step
# Epoch 14/80
#
# Epoch 14: loss improved from 0.01664 to 0.01581, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0158 - 3s/epoch - 156ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.01581 to 0.01573, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0157 - 3s/epoch - 151ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.01573
# 18/18 - 3s - loss: 0.0162 - 3s/epoch - 149ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.01573
# 18/18 - 4s - loss: 0.0159 - 4s/epoch - 210ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.01573
# 18/18 - 3s - loss: 0.0175 - 3s/epoch - 189ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.01573
# 18/18 - 3s - loss: 0.0168 - 3s/epoch - 152ms/step
# Epoch 20/80
#
# Epoch 20: loss improved from 0.01573 to 0.01547, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0155 - 3s/epoch - 168ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.01547
# 18/18 - 3s - loss: 0.0187 - 3s/epoch - 160ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.01547
# 18/18 - 5s - loss: 0.0190 - 5s/epoch - 287ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.01547
# 18/18 - 3s - loss: 0.0203 - 3s/epoch - 153ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.01547 to 0.01534, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0153 - 3s/epoch - 167ms/step
# Epoch 25/80
#
# Epoch 25: loss improved from 0.01534 to 0.01402, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0140 - 3s/epoch - 157ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.01402
# 18/18 - 4s - loss: 0.0142 - 4s/epoch - 250ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.01402
# 18/18 - 3s - loss: 0.0143 - 3s/epoch - 154ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.01402
# 18/18 - 3s - loss: 0.0142 - 3s/epoch - 154ms/step
# Epoch 29/80
#
# Epoch 29: loss improved from 0.01402 to 0.01371, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0137 - 3s/epoch - 166ms/step
# Epoch 30/80
#
# Epoch 30: loss improved from 0.01371 to 0.01371, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 4s - loss: 0.0137 - 4s/epoch - 215ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.01371
# 18/18 - 3s - loss: 0.0190 - 3s/epoch - 192ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.01371
# 18/18 - 3s - loss: 0.0155 - 3s/epoch - 151ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.01371
# 18/18 - 3s - loss: 0.0172 - 3s/epoch - 149ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.01371
# 18/18 - 3s - loss: 0.0159 - 3s/epoch - 148ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.01371
# 18/18 - 5s - loss: 0.0145 - 5s/epoch - 251ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.01371
# 18/18 - 3s - loss: 0.0146 - 3s/epoch - 151ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.01371
# 18/18 - 4s - loss: 0.0153 - 4s/epoch - 196ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.01371
# 18/18 - 3s - loss: 0.0149 - 3s/epoch - 147ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.01371
# 18/18 - 4s - loss: 0.0148 - 4s/epoch - 236ms/step
# Epoch 40/80
#
# Epoch 40: loss improved from 0.01371 to 0.01350, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0135 - 3s/epoch - 186ms/step
# Epoch 41/80
#
# Epoch 41: loss improved from 0.01350 to 0.01324, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0132 - 3s/epoch - 153ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.01324
# 18/18 - 3s - loss: 0.0139 - 3s/epoch - 149ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.01324
# 18/18 - 3s - loss: 0.0140 - 3s/epoch - 183ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.01324
# 18/18 - 4s - loss: 0.0132 - 4s/epoch - 218ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.01324
# 18/18 - 3s - loss: 0.0140 - 3s/epoch - 152ms/step
# Epoch 46/80
#
# Epoch 46: loss improved from 0.01324 to 0.01300, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0130 - 3s/epoch - 162ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.01300
# 18/18 - 3s - loss: 0.0139 - 3s/epoch - 151ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.01300
# 18/18 - 4s - loss: 0.0141 - 4s/epoch - 250ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.01300
# 18/18 - 3s - loss: 0.0146 - 3s/epoch - 149ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.01300
# 18/18 - 3s - loss: 0.0138 - 3s/epoch - 151ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.01300
# 18/18 - 3s - loss: 0.0136 - 3s/epoch - 149ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.01300
# 18/18 - 3s - loss: 0.0141 - 3s/epoch - 185ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.01300
# 18/18 - 4s - loss: 0.0149 - 4s/epoch - 218ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.01300
# 18/18 - 3s - loss: 0.0137 - 3s/epoch - 154ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.01300
# 18/18 - 3s - loss: 0.0136 - 3s/epoch - 153ms/step
# Epoch 56/80
#
# Epoch 56: loss improved from 0.01300 to 0.01279, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5
# 18/18 - 4s - loss: 0.0128 - 4s/epoch - 215ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.01279
# 18/18 - 4s - loss: 0.0151 - 4s/epoch - 234ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0144 - 3s/epoch - 150ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0138 - 3s/epoch - 146ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0131 - 3s/epoch - 148ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.01279
# 18/18 - 4s - loss: 0.0133 - 4s/epoch - 221ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0135 - 3s/epoch - 177ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0137 - 3s/epoch - 148ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0135 - 3s/epoch - 153ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0156 - 3s/epoch - 157ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.01279
# 18/18 - 4s - loss: 0.0137 - 4s/epoch - 248ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0142 - 3s/epoch - 152ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0142 - 3s/epoch - 151ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0147 - 3s/epoch - 152ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.01279
# 18/18 - 4s - loss: 0.0130 - 4s/epoch - 211ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0158 - 3s/epoch - 192ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0148 - 3s/epoch - 152ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0137 - 3s/epoch - 153ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0141 - 3s/epoch - 151ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.01279
# 18/18 - 5s - loss: 0.0131 - 5s/epoch - 250ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0129 - 3s/epoch - 152ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0132 - 3s/epoch - 153ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.01279
# 18/18 - 3s - loss: 0.0141 - 3s/epoch - 150ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.01279
# 18/18 - 4s - loss: 0.0156 - 4s/epoch - 200ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.01279
# 18/18 - 4s - loss: 0.0150 - 4s/epoch - 198ms/step

# %% [markdown]
# ## Eval

# %%
y_train = scaler.inverse_transform(y_train)

final_model = load_model('/content/drive/MyDrive/IS403/Project/Model/GRU_AMZ_721.hdf5')

y_train_predict = final_model.predict(x_train)

y_train_predict = scaler.inverse_transform(y_train_predict)
# Out:
# 28/28 [==============================] - 2s 33ms/step

# %%
test = close_amz[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = scaler.transform(test)

x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data_amz[train_size:train_size+test_size]  # True values

y_test_predict = final_model.predict(x_test)

y_test_predict = scaler.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 0s 31ms/step

# %%
val = close_amz[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = scaler.transform(val)

x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

y_val = data_amz[train_size+test_size:]  # True values

y_val_predict = final_model.predict(x_val)

y_val_predict = scaler.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 32ms/step

# %%
train_data = close_amz[:train_size]
test_data = close_amz[train_size:train_size+test_size]
val_data = close_amz[train_size+test_size:]

# %%
eval(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  2.970593185698471
# MAPE:  2.2399040843561804
# RMSE:  3.99091493304205
#
# ** Validate **
# MAE:  1.813905819231306
# MAPE:  1.8138058564032913
# RMSE:  2.3137537652507434

# %% [markdown]
# ## Predict

# %%
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)
print(x_input.shape)

temp_input = list(x_input)
temp_input = temp_input[0].tolist()
print(temp_input)
# Out:
# (1, 100)
# [0.2984646662272322, 0.2847589766119052, 0.3122473695417426, 0.3143263005293834, 0.3050865276860706, 0.3117083814450792, 0.3274160422476733, 0.3506695056042365, 0.33765683148393943, 0.3575223465619851, 0.3730760415648524, 0.4328267373946353, 0.3595243177492522, 0.3502075312067563, 0.34966855080992276, 0.3338069165077717, 0.3198701857948948, 0.31501931602441324, 0.3298799878324208, 0.33111192982547455, 0.34235373545469394, 0.31917723189850444, 0.311862354944636, 0.2916888389686668, 0.30100562551116283, 0.3012366127099029, 0.28337300722048475, 0.28537497840775183, 0.2889939061851794, 0.2731322179842187, 0.27282421708629534, 0.2941527845534142, 0.2852979647085686, 0.28375802181759135, 0.2866069204008057, 0.27374821978006547, 0.2620445013520054, 0.2751341891714859, 0.29399874945521776, 0.30416252499230056, 0.3337299028085885, 0.325337057361223, 0.3157892836199869, 0.3381188058814196, 0.3234120998731391, 0.32348911357232235, 0.319023196800308, 0.31833024290391754, 0.31217035584255937, 0.33534685939874886, 0.34882156181533597, 0.3587543501536786, 0.3519785228951132, 0.3638362071229001, 0.3418916994585741, 0.34928353621281605, 0.35013051750757307, 0.33280590011481836, 0.31671328631375706, 0.35190150919593, 0.3527484904906869, 0.3545194205804042, 0.3511315339005264, 0.3665311938051973, 0.36275823862940315, 0.3870127106790897, 0.38123783821483814, 0.3532104648881671, 0.3717670781727853, 0.4090342320425989, 0.37538595205140324, 0.34920657641244257, 0.36137226153815283, 0.3615262966363493, 0.3642212217200068, 0.37700297024020346, 0.37831192593244045, 0.3843947992946155, 0.41188318452462314, 0.42720583073011065, 0.41242217262128655, 0.41965997427733204, 0.43659963867161977, 0.4527692661718643, 0.47317383094521315, 0.45854413863611587, 0.4489963648948798, 0.44884233749651326, 0.4623940536122836, 0.4489193511956966, 0.4882654899519606, 0.5002002494775704, 0.4918844177293882, 0.508747006825853, 0.5201427782547994, 0.5282276228042414, 0.5383143846421409, 0.4968893148982362, 0.5201427782547994, 0.5138289176938843]

# %%
lst_output = []
n_steps = 100
i = 0

while(i < 30):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())

        lst_output.extend(yhat.tolist())
        i += 1

print(lst_output)
# Out:
# [[0.513070285320282], [0.5114141702651978], [0.5098699927330017], [0.5083761215209961], [0.506895899772644], [0.5054216384887695], [0.503949761390686], [0.5024789571762085], [0.5010086894035339], [0.499538779258728], [0.4980689585208893], [0.4965991973876953], [0.49512940645217896], [0.49365925788879395], [0.49218857288360596], [0.4907173812389374], [0.48924556374549866], [0.4877731204032898], [0.4862997233867645], [0.48482537269592285], [0.48335009813308716], [0.4818737208843231], [0.48039618134498596], [0.4789174497127533], [0.4774375855922699], [0.47595617175102234], [0.47447338700294495], [0.47298920154571533], [0.4715035855770111], [0.4700165092945099]]

# %%
datelist_train = df_amz['Date'].astype(str).tolist()

datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
y_pred_future = scaler.inverse_transform(lst_output)

print(y_pred_future)
# Out:
# [[123.33147414]
#  [123.11638951]
#  [122.91584255]
#  [122.72182901]
#  [122.52958818]
#  [122.33812144]
#  [122.14696435]
#  [121.9559466 ]
#  [121.76499852]
#  [121.57409688]
#  [121.38320685]
#  [121.19232457]
#  [121.00143841]
#  [120.81050581]
#  [120.61950354]
#  [120.42843547]
#  [120.23728612]
#  [120.04605549]
#  [119.854701  ]
#  [119.66322266]
#  [119.47162433]
#  [119.27988279]
#  [119.0879903 ]
#  [118.89594299]
#  [118.7037486 ]
#  [118.51135294]
#  [118.31877924]
#  [118.12602363]
#  [117.93308223]
#  [117.73995117]]

# %%
y_pred_future = scaler.inverse_transform(lst_output)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Close']).set_index(pd.Series(datelist_future))

plt.figure(figsize=(16,5))
plt.plot(train_data.index[train_size-100:], train_data.Close[train_size-100:])
plt.plot(test_data)

plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('AMZ Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction','30 days'])
plt.show()

# %% [markdown]
# # NVIDIA

# %% [markdown]
# ## Data

# %%
df_nvda = pd.read_csv("NVDA.csv")
df_nvda
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2017-12-01   49.827499   50.032501   48.117500   49.419998   48.908009
# 1     2017-12-04   50.012501   50.075001   46.125000   46.665001   46.181549
# 2     2017-12-05   45.599998   48.174999   45.145000   46.935001   46.448750
# 3     2017-12-06   46.424999   47.535000   46.209999   47.314999   46.824821
# 4     2017-12-07   47.990002   48.400002   47.529999   47.997501   47.500244
# ...          ...         ...         ...         ...         ...         ...
# 1384  2023-06-05  389.089996  395.649994  387.070007  391.709991  391.669464
# 1385  2023-06-06  388.299988  391.600006  381.480011  386.540009  386.500000
# 1386  2023-06-07  389.149994  394.989990  373.559998  374.750000  374.750000
# 1387  2023-06-08  377.239990  388.640015  375.049988  385.100006  385.100006
# 1388  2023-06-09  390.369995  397.109985  385.670013  387.700012  387.700012
#
#          Volume
# 0      81154800
# 1     124084400
# 2      98148800
# 3      46703200
# 4      54260000
# ...         ...
# 1384   39609400
# 1385   38872900
# 1386   51199800
# 1387   41777200
# 1388   42722000
#
# [1389 rows x 7 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Check null and na value

# %%
df_nvda.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_nvda.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Check datatype of each column

# %%
print("Date column data type: ", type(df_nvda['Date'][0]))
print("Open column data type: ", type(df_nvda['Open'][0]))
print("Close column data type: ", type(df_nvda['Close'][0]))
print("High column data type: ", type(df_nvda['High'][0]))
print("Low column data type: ", type(df_nvda['Low'][0]))
print("Adj Close column data type: ", type(df_nvda['Adj Close'][0]))
print("Volume column data type: ", type(df_nvda['Low'][0]))
# Out:
# Date column data type:  <class 'str'>
# Open column data type:  <class 'numpy.float64'>
# Close column data type:  <class 'numpy.float64'>
# High column data type:  <class 'numpy.float64'>
# Low column data type:  <class 'numpy.float64'>
# Adj Close column data type:  <class 'numpy.float64'>
# Volume column data type:  <class 'numpy.float64'>

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Get the duration of dataset

# %%
print("Starting date: ",df_nvda.iloc[0][0])
print("Ending date: ", df_nvda.iloc[-1][0])
# Out:
# Starting date:  2017-12-01
# Ending date:  2023-06-09

# %% [markdown]
# ### Visualize the per day closing price of the stock

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(df_nvda['Close'])
plt.title('NVIDIA closing price')
plt.show()

# %% [markdown]
# ## Train, test, valid

# %% [markdown]
# ### Convert date from string to date format & reset index

# %%
df_nvda = df_nvda.set_index(pd.DatetimeIndex(df_nvda['Date'].values))

df_nvda.index = pd.to_datetime(df_nvda.index,format='%Y-%m-%d')

close_nvda = pd.DataFrame(df_nvda, columns=['Date', 'Close'])
close_nvda.drop('Date', axis = 1, inplace = True)

# %% [markdown]
# ### Split

# %%
data_nvda = close_nvda.values
scaler = MinMaxScaler(feature_range=(0, 1))

sc_train = scaler.fit_transform(data_nvda)

train_data, test_data, valid_data, train_size, test_size, val_size = train_test_valid(sc_train)

# %%
x_train, y_train = [], []

for i in range(100, len(train_data)):
    x_train.append(sc_train[i-100:i, 0])
    y_train.append(sc_train[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %% [markdown]
# ## Build & train model

# %%
model = Sequential()

model.add(GRU(50,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(GRU(50,return_sequences=True))
model.add(GRU(50))
model.add(Dense(1))

model.compile(loss='mean_absolute_error', optimizer='adam')

save_model = '/content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5'

best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.06392, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 10s - loss: 0.0639 - 10s/epoch - 539ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.06392 to 0.01301, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0130 - 3s/epoch - 156ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.01301 to 0.00993, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 4s - loss: 0.0099 - 4s/epoch - 249ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.00993 to 0.00933, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0093 - 3s/epoch - 160ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.00933 to 0.00918, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0092 - 3s/epoch - 157ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.00918 to 0.00910, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0091 - 3s/epoch - 148ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.00910 to 0.00804, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0080 - 3s/epoch - 194ms/step
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.00804
# 18/18 - 4s - loss: 0.0083 - 4s/epoch - 211ms/step
# Epoch 9/80
#
# Epoch 9: loss did not improve from 0.00804
# 18/18 - 3s - loss: 0.0088 - 3s/epoch - 158ms/step
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.00804
# 18/18 - 3s - loss: 0.0081 - 3s/epoch - 157ms/step
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.00804
# 18/18 - 3s - loss: 0.0084 - 3s/epoch - 153ms/step
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.00804
# 18/18 - 5s - loss: 0.0081 - 5s/epoch - 252ms/step
# Epoch 13/80
#
# Epoch 13: loss improved from 0.00804 to 0.00698, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0070 - 3s/epoch - 167ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.00698
# 18/18 - 3s - loss: 0.0081 - 3s/epoch - 152ms/step
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.00698
# 18/18 - 3s - loss: 0.0073 - 3s/epoch - 151ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.00698
# 18/18 - 4s - loss: 0.0079 - 4s/epoch - 225ms/step
# Epoch 17/80
#
# Epoch 17: loss improved from 0.00698 to 0.00697, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 4s - loss: 0.0070 - 4s/epoch - 200ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.00697
# 18/18 - 3s - loss: 0.0075 - 3s/epoch - 154ms/step
# Epoch 19/80
#
# Epoch 19: loss improved from 0.00697 to 0.00694, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0069 - 3s/epoch - 156ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.00694
# 18/18 - 3s - loss: 0.0074 - 3s/epoch - 191ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.00694
# 18/18 - 4s - loss: 0.0072 - 4s/epoch - 216ms/step
# Epoch 22/80
#
# Epoch 22: loss improved from 0.00694 to 0.00687, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0069 - 3s/epoch - 170ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.00687
# 18/18 - 3s - loss: 0.0071 - 3s/epoch - 155ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.00687 to 0.00621, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0062 - 3s/epoch - 155ms/step
# Epoch 25/80
#
# Epoch 25: loss improved from 0.00621 to 0.00584, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 4s - loss: 0.0058 - 4s/epoch - 249ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.00584
# 18/18 - 3s - loss: 0.0062 - 3s/epoch - 153ms/step
# Epoch 27/80
#
# Epoch 27: loss improved from 0.00584 to 0.00579, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0058 - 3s/epoch - 156ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.00579
# 18/18 - 3s - loss: 0.0067 - 3s/epoch - 154ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.00579
# 18/18 - 4s - loss: 0.0059 - 4s/epoch - 219ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.00579
# 18/18 - 3s - loss: 0.0060 - 3s/epoch - 183ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.00579
# 18/18 - 3s - loss: 0.0059 - 3s/epoch - 155ms/step
# Epoch 32/80
#
# Epoch 32: loss improved from 0.00579 to 0.00571, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0057 - 3s/epoch - 166ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.00571
# 18/18 - 3s - loss: 0.0069 - 3s/epoch - 162ms/step
# Epoch 34/80
#
# Epoch 34: loss improved from 0.00571 to 0.00560, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 5s - loss: 0.0056 - 5s/epoch - 255ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.00560
# 18/18 - 3s - loss: 0.0058 - 3s/epoch - 153ms/step
# Epoch 36/80
#
# Epoch 36: loss improved from 0.00560 to 0.00524, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0052 - 3s/epoch - 154ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0059 - 3s/epoch - 153ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.00524
# 18/18 - 4s - loss: 0.0058 - 4s/epoch - 245ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0068 - 3s/epoch - 162ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0062 - 3s/epoch - 153ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0056 - 3s/epoch - 156ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0057 - 3s/epoch - 192ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.00524
# 18/18 - 4s - loss: 0.0062 - 4s/epoch - 213ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0053 - 3s/epoch - 150ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0058 - 3s/epoch - 155ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0058 - 3s/epoch - 156ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.00524
# 18/18 - 5s - loss: 0.0082 - 5s/epoch - 252ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0060 - 3s/epoch - 152ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0063 - 3s/epoch - 154ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0080 - 3s/epoch - 155ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.00524
# 18/18 - 4s - loss: 0.0064 - 4s/epoch - 204ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.00524
# 18/18 - 4s - loss: 0.0063 - 4s/epoch - 199ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0056 - 3s/epoch - 148ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0061 - 3s/epoch - 154ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0062 - 3s/epoch - 151ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.00524
# 18/18 - 4s - loss: 0.0056 - 4s/epoch - 248ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0055 - 3s/epoch - 154ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0054 - 3s/epoch - 153ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0053 - 3s/epoch - 153ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.00524
# 18/18 - 4s - loss: 0.0053 - 4s/epoch - 197ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.00524
# 18/18 - 4s - loss: 0.0057 - 4s/epoch - 207ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0057 - 3s/epoch - 151ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.00524
# 18/18 - 3s - loss: 0.0059 - 3s/epoch - 153ms/step
# Epoch 64/80
#
# Epoch 64: loss improved from 0.00524 to 0.00523, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0052 - 3s/epoch - 170ms/step
# Epoch 65/80
#
# Epoch 65: loss improved from 0.00523 to 0.00516, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 5s - loss: 0.0052 - 5s/epoch - 254ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.00516
# 18/18 - 3s - loss: 0.0057 - 3s/epoch - 154ms/step
# Epoch 67/80
#
# Epoch 67: loss improved from 0.00516 to 0.00511, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0051 - 3s/epoch - 154ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.00511
# 18/18 - 3s - loss: 0.0059 - 3s/epoch - 154ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.00511
# 18/18 - 4s - loss: 0.0062 - 4s/epoch - 230ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.00511
# 18/18 - 3s - loss: 0.0051 - 3s/epoch - 178ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.00511
# 18/18 - 3s - loss: 0.0053 - 3s/epoch - 150ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.00511
# 18/18 - 3s - loss: 0.0061 - 3s/epoch - 155ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.00511
# 18/18 - 3s - loss: 0.0060 - 3s/epoch - 169ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.00511
# 18/18 - 4s - loss: 0.0059 - 4s/epoch - 237ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.00511
# 18/18 - 3s - loss: 0.0070 - 3s/epoch - 156ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.00511
# 18/18 - 3s - loss: 0.0061 - 3s/epoch - 154ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.00511
# 18/18 - 3s - loss: 0.0057 - 3s/epoch - 156ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.00511
# 18/18 - 4s - loss: 0.0058 - 4s/epoch - 235ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.00511
# 18/18 - 3s - loss: 0.0052 - 3s/epoch - 166ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.00511
# 18/18 - 3s - loss: 0.0055 - 3s/epoch - 154ms/step

# %% [markdown]
# ## Eval

# %%
y_train = scaler.inverse_transform(y_train)

final_model = load_model('/content/drive/MyDrive/IS403/Project/Model/GRU_NVDA_721.hdf5')

y_train_predict = final_model.predict(x_train)

y_train_predict = scaler.inverse_transform(y_train_predict)
# Out:
# 28/28 [==============================] - 2s 33ms/step

# %%
test = close_nvda[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = scaler.transform(test)

x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data_nvda[train_size:train_size+test_size]  # True values

y_test_predict = final_model.predict(x_test)

y_test_predict = scaler.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 0s 33ms/step

# %%
val = close_nvda[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = scaler.transform(val)

x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

y_val = data_nvda[train_size+test_size:]  # True values

y_val_predict = final_model.predict(x_val)

y_val_predict = scaler.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 33ms/step

# %%
train_data = close_nvda[:train_size]
test_data = close_nvda[train_size:train_size+test_size]
val_data = close_nvda[train_size+test_size:]

# %%
eval(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  7.297977448513651
# MAPE:  3.401695714365998
# RMSE:  9.666607808168363
#
# ** Validate **
# MAE:  7.529044698130581
# MAPE:  3.0465659607458164
# RMSE:  11.851811755705453

# %% [markdown]
# ## Predict

# %%
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)
print(x_input.shape)

temp_input = list(x_input)
temp_input = temp_input[0].tolist()
print(temp_input)
# Out:
# (1, 100)
# [0.3844696208562417, 0.36789949509528463, 0.3969784073067528, 0.4336383806372873, 0.43558780671960007, 0.4371581809643491, 0.4501272831318277, 0.4653706638342988, 0.4327990509882107, 0.44295229773185796, 0.4810201987743081, 0.5017599055785958, 0.48527104369704244, 0.4849732124183629, 0.5143228562160688, 0.5151892855575873, 0.5187632067510913, 0.4897384560190524, 0.5038988805937163, 0.5359289950694073, 0.5303243812066543, 0.5096929973612253, 0.49306875073382583, 0.4732225323505116, 0.4759029624155099, 0.5546921733914079, 0.5444577060888763, 0.5502788846433726, 0.5425624414859929, 0.528537401657175, 0.5452158097640036, 0.5608111832245837, 0.5517138714347433, 0.5445118675683056, 0.5686901135277839, 0.5485190047863352, 0.5357665079235869, 0.5357936103235613, 0.5654952441718434, 0.5699626564938535, 0.6055125712966062, 0.610494420202026, 0.615232602015728, 0.6233280970106715, 0.6306113674640453, 0.6501868569686545, 0.6390318367506296, 0.6323171264546403, 0.6290410338322833, 0.6445822431059014, 0.65538527327335, 0.6660529566004071, 0.6711431311722178, 0.6572805784892203, 0.6417934900820446, 0.6460172326048045, 0.6606920964704105, 0.6495911944112955, 0.6313424526727047, 0.6304760233311862, 0.6384631953672711, 0.6450695799968692, 0.6630747358697162, 0.670222580964257, 0.6478313172617906, 0.6482374281788092, 0.6461526579636374, 0.6244652985514146, 0.643824139430774, 0.6511345095765897, 0.665294850217747, 0.6967293454565987, 0.6777766182017904, 0.6667298397166502, 0.6602317780459107, 0.6905019720515773, 0.7032545095273126, 0.6875507697873545, 0.6960524623403556, 0.6877403187201623, 0.6812963779158652, 0.6978935654638095, 0.7049331661179332, 0.7310608381597241, 0.7716738251343135, 0.7604646840498464, 0.7580820419430081, 0.7448692699762793, 0.7408079712788204, 0.9423024912940307, 0.9684572630282636, 0.9999999999999999, 0.9383495155554306, 0.9907673873978199, 0.9787729563047444, 0.9745492110744521, 0.960551316966128, 0.9286294848363087, 0.9566524620939701, 0.9636920627480937]

# %%
lst_output = []
n_steps = 100
i = 0

while(i < 30):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())

        lst_output.extend(yhat.tolist())
        i += 1

print(lst_output)
# Out:
# [[0.9373156428337097], [0.8953408598899841], [0.8595837950706482], [0.8357671499252319], [0.8186020255088806], [0.8023064732551575], [0.7850584983825684], [0.7677909135818481], [0.7517307996749878], [0.7372490167617798], [0.7240535616874695], [0.7117484211921692], [0.700124204158783], [0.6891395449638367], [0.6788005828857422], [0.6690875887870789], [0.6599496603012085], [0.6513274908065796], [0.6431704759597778], [0.6354402303695679], [0.6281052231788635], [0.6211369037628174], [0.6145081520080566], [0.608193576335907], [0.6021697521209717], [0.5964156985282898], [0.5909123420715332], [0.5856426358222961], [0.5805906653404236], [0.5757424235343933]]

# %%
datelist_train = df_nvda['Date'].astype(str).tolist()

datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
y_pred_future = scaler.inverse_transform(lst_output)

print(y_pred_future)
# Out:
# [[377.95814546]
#  [362.45517976]
#  [349.24866598]
#  [340.45222662]
#  [334.11245982]
#  [328.0938608 ]
#  [321.72349402]
#  [315.34588451]
#  [309.41424228]
#  [304.06554079]
#  [299.19193161]
#  [294.64715121]
#  [290.35386306]
#  [286.2967892 ]
#  [282.4781971 ]
#  [278.89080001]
#  [275.51579764]
#  [272.33128568]
#  [269.31857394]
#  [266.46348515]
#  [263.75437371]
#  [261.18069472]
#  [258.73243165]
#  [256.40020636]
#  [254.17536722]
#  [252.05016515]
#  [250.01755556]
#  [248.07124233]
#  [246.20534763]
#  [244.41469807]]

# %%
y_pred_future = scaler.inverse_transform(lst_output)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Close']).set_index(pd.Series(datelist_future))

plt.figure(figsize=(16,5))

plt.plot(train_data.index[train_size-100:], train_data.Close[train_size-100:])
plt.plot(test_data)

plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('NVIDIA Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction','30 days'])
plt.show()

# %% [markdown]
# # TESLA

# %% [markdown]
# ## Data

# %%
df_tsla = pd.read_csv("TSLA.csv")
df_tsla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2017-12-01   20.362667   20.688000   20.336666   20.435333   20.435333
# 1     2017-12-04   20.433332   20.551332   20.040667   20.346666   20.346666
# 2     2017-12-05   20.133333   20.533333   20.066668   20.246668   20.246668
# 3     2017-12-06   20.006666   20.892668   20.000000   20.884001   20.884001
# 4     2017-12-07   20.799999   21.242001   20.736668   20.749332   20.749332
# ...          ...         ...         ...         ...         ...         ...
# 1384  2023-06-05  217.800003  221.289993  214.520004  217.610001  217.610001
# 1385  2023-06-06  216.139999  221.910004  212.529999  221.309998  221.309998
# 1386  2023-06-07  228.000000  230.830002  223.199997  224.570007  224.570007
# 1387  2023-06-08  224.220001  235.229996  223.009995  234.860001  234.860001
# 1388  2023-06-09  249.070007  252.419998  242.020004  244.399994  244.399994
#
#          Volume
# 0      64393500
# 1      87526500
# 2      69697500
# 3     107929500
# 4      71709000
# ...         ...
# 1384  151143100
# 1385  146911600
# 1386  185710800
# 1387  164489700
# 1388  199882300
#
# [1389 rows x 7 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Check null and na value

# %%
df_tsla.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_tsla.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Check datatype of each column

# %%
print("Date column data type: ", type(df_tsla['Date'][0]))
print("Open column data type: ", type(df_tsla['Open'][0]))
print("Close column data type: ", type(df_tsla['Close'][0]))
print("High column data type: ", type(df_tsla['High'][0]))
print("Low column data type: ", type(df_tsla['Low'][0]))
print("Adj Close column data type: ", type(df_tsla['Adj Close'][0]))
print("Volume column data type: ", type(df_tsla['Low'][0]))
# Out:
# Date column data type:  <class 'str'>
# Open column data type:  <class 'numpy.float64'>
# Close column data type:  <class 'numpy.float64'>
# High column data type:  <class 'numpy.float64'>
# Low column data type:  <class 'numpy.float64'>
# Adj Close column data type:  <class 'numpy.float64'>
# Volume column data type:  <class 'numpy.float64'>

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Get the duration of dataset

# %%
print("Starting date: ",df_tsla.iloc[0][0])
print("Ending date: ", df_tsla.iloc[-1][0])
# Out:
# Starting date:  2017-12-01
# Ending date:  2023-06-09

# %% [markdown]
# ### Visualize the per day closing price of the stock

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(df_tsla['Close'])
plt.title('TESLA closing price')
plt.show()

# %% [markdown]
# ## Train, test, valid

# %% [markdown]
# ### Convert date from string to date format & reset index

# %%
df_tsla = df_tsla.set_index(pd.DatetimeIndex(df_tsla['Date'].values))

df_tsla.index = pd.to_datetime(df_tsla.index,format='%Y-%m-%d')

close_tsla = pd.DataFrame(df_tsla, columns=['Date', 'Close'])
close_tsla.drop('Date', axis = 1, inplace = True)

# %% [markdown]
# ### Split

# %%
data_tsla = close_tsla.values
scaler = MinMaxScaler(feature_range=(0, 1))

sc_train = scaler.fit_transform(data_tsla)

train_data, test_data, valid_data, train_size, test_size, val_size = train_test_valid(sc_train)

# %%
x_train, y_train = [], []

for i in range(100, len(train_data)):
    x_train.append(sc_train[i-100:i, 0])
    y_train.append(sc_train[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %% [markdown]
# ## Build model

# %%
model = Sequential()

model.add(GRU(50,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(GRU(50,return_sequences=True))
model.add(GRU(50))
model.add(Dense(1))

model.compile(loss='mean_absolute_error', optimizer='adam')

save_model = '/content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5'

best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.08525, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 10s - loss: 0.0852 - 10s/epoch - 572ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.08525 to 0.02462, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0246 - 3s/epoch - 149ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.02462 to 0.01817, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0182 - 4s/epoch - 202ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.01817 to 0.01468, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0147 - 4s/epoch - 208ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.01468 to 0.01205, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0120 - 3s/epoch - 150ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.01205 to 0.01085, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0109 - 3s/epoch - 151ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.01085 to 0.01011, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0101 - 3s/epoch - 151ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.01011 to 0.00947, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0095 - 4s/epoch - 246ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.00947 to 0.00915, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0091 - 3s/epoch - 160ms/step
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.00915
# 18/18 - 3s - loss: 0.0095 - 3s/epoch - 147ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.00915 to 0.00911, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0091 - 3s/epoch - 151ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.00911 to 0.00906, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0091 - 3s/epoch - 184ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.00906
# 18/18 - 4s - loss: 0.0114 - 4s/epoch - 217ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.00906
# 18/18 - 3s - loss: 0.0095 - 3s/epoch - 153ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.00906 to 0.00867, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0087 - 3s/epoch - 166ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.00867
# 18/18 - 3s - loss: 0.0114 - 3s/epoch - 148ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.00867
# 18/18 - 5s - loss: 0.0103 - 5s/epoch - 291ms/step
# Epoch 18/80
#
# Epoch 18: loss improved from 0.00867 to 0.00837, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0084 - 3s/epoch - 162ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.00837
# 18/18 - 3s - loss: 0.0096 - 3s/epoch - 144ms/step
# Epoch 20/80
#
# Epoch 20: loss improved from 0.00837 to 0.00817, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0082 - 3s/epoch - 148ms/step
# Epoch 21/80
#
# Epoch 21: loss improved from 0.00817 to 0.00740, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0074 - 4s/epoch - 212ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.00740
# 18/18 - 3s - loss: 0.0078 - 3s/epoch - 187ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.00740
# 18/18 - 3s - loss: 0.0084 - 3s/epoch - 144ms/step
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.00740
# 18/18 - 3s - loss: 0.0105 - 3s/epoch - 149ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.00740
# 18/18 - 3s - loss: 0.0098 - 3s/epoch - 152ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.00740
# 18/18 - 4s - loss: 0.0076 - 4s/epoch - 248ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.00740
# 18/18 - 3s - loss: 0.0075 - 3s/epoch - 146ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.00740
# 18/18 - 3s - loss: 0.0077 - 3s/epoch - 147ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.00740
# 18/18 - 3s - loss: 0.0079 - 3s/epoch - 146ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.00740
# 18/18 - 3s - loss: 0.0079 - 3s/epoch - 164ms/step
# Epoch 31/80
#
# Epoch 31: loss improved from 0.00740 to 0.00678, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0068 - 4s/epoch - 235ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.00678
# 18/18 - 3s - loss: 0.0081 - 3s/epoch - 145ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.00678
# 18/18 - 3s - loss: 0.0093 - 3s/epoch - 151ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.00678
# 18/18 - 3s - loss: 0.0074 - 3s/epoch - 146ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.00678
# 18/18 - 4s - loss: 0.0076 - 4s/epoch - 214ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.00678
# 18/18 - 3s - loss: 0.0077 - 3s/epoch - 174ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.00678
# 18/18 - 3s - loss: 0.0080 - 3s/epoch - 144ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.00678
# 18/18 - 3s - loss: 0.0097 - 3s/epoch - 148ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.00678
# 18/18 - 3s - loss: 0.0137 - 3s/epoch - 144ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.00678
# 18/18 - 4s - loss: 0.0112 - 4s/epoch - 248ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.00678
# 18/18 - 3s - loss: 0.0071 - 3s/epoch - 143ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.00678
# 18/18 - 3s - loss: 0.0068 - 3s/epoch - 144ms/step
# Epoch 43/80
#
# Epoch 43: loss improved from 0.00678 to 0.00674, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0067 - 3s/epoch - 166ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0071 - 3s/epoch - 177ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.00674
# 18/18 - 4s - loss: 0.0073 - 4s/epoch - 212ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0076 - 3s/epoch - 143ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0072 - 3s/epoch - 145ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0074 - 3s/epoch - 144ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.00674
# 18/18 - 4s - loss: 0.0074 - 4s/epoch - 209ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0068 - 3s/epoch - 181ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0071 - 3s/epoch - 144ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0069 - 3s/epoch - 178ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0074 - 3s/epoch - 144ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.00674
# 18/18 - 4s - loss: 0.0086 - 4s/epoch - 238ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0090 - 3s/epoch - 141ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0073 - 3s/epoch - 144ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0078 - 3s/epoch - 144ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0081 - 3s/epoch - 178ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.00674
# 18/18 - 4s - loss: 0.0070 - 4s/epoch - 217ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0072 - 3s/epoch - 146ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0070 - 3s/epoch - 143ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0068 - 3s/epoch - 146ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.00674
# 18/18 - 4s - loss: 0.0074 - 4s/epoch - 210ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0080 - 3s/epoch - 181ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0071 - 3s/epoch - 141ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0072 - 3s/epoch - 145ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0078 - 3s/epoch - 143ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.00674
# 18/18 - 4s - loss: 0.0070 - 4s/epoch - 239ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.00674
# 18/18 - 3s - loss: 0.0076 - 3s/epoch - 147ms/step
# Epoch 70/80
#
# Epoch 70: loss improved from 0.00674 to 0.00673, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0067 - 3s/epoch - 158ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.00673
# 18/18 - 3s - loss: 0.0075 - 3s/epoch - 147ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.00673
# 18/18 - 3s - loss: 0.0085 - 3s/epoch - 165ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.00673
# 18/18 - 4s - loss: 0.0087 - 4s/epoch - 226ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.00673
# 18/18 - 3s - loss: 0.0079 - 3s/epoch - 144ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.00673
# 18/18 - 3s - loss: 0.0069 - 3s/epoch - 147ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.00673
# 18/18 - 3s - loss: 0.0067 - 3s/epoch - 147ms/step
# Epoch 77/80
#
# Epoch 77: loss improved from 0.00673 to 0.00664, saving model to /content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0066 - 4s/epoch - 224ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.00664
# 18/18 - 3s - loss: 0.0069 - 3s/epoch - 173ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.00664
# 18/18 - 3s - loss: 0.0067 - 3s/epoch - 147ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.00664
# 18/18 - 3s - loss: 0.0071 - 3s/epoch - 151ms/step

# %% [markdown]
# ## Eval

# %%
y_train = scaler.inverse_transform(y_train)

final_model = load_model('/content/drive/MyDrive/IS403/Project/Model/GRU_TSLA_721.hdf5')

y_train_predict = final_model.predict(x_train)

y_train_predict = scaler.inverse_transform(y_train_predict)
# Out:
# 28/28 [==============================] - 2s 30ms/step

# %%
test = close_tsla[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = scaler.transform(test)

x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data_tsla[train_size:train_size+test_size]  # True values

y_test_predict = final_model.predict(x_test)

y_test_predict = scaler.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 0s 29ms/step

# %%
val = close_tsla[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = scaler.transform(val)

x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

y_val = data_tsla[train_size+test_size:]  # True values

y_val_predict = final_model.predict(x_val)

y_val_predict = scaler.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 31ms/step

# %%
train_data = close_tsla[:train_size]
test_data = close_tsla[train_size:train_size+test_size]
val_data = close_tsla[train_size+test_size:]

# %%
eval(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  9.46166099620304
# MAPE:  3.256359401249883
# RMSE:  12.444814708510657
#
# ** Validate **
# MAE:  5.241785694705636
# MAPE:  3.0863229347777974
# RMSE:  6.790236189458381

# %% [markdown]
# ## Predict

# %%
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)
print(x_input.shape)

temp_input = list(x_input)
temp_input = temp_input[0].tolist()
print(temp_input)
# Out:
# (1, 100)
# [0.2935610919087891, 0.28951625624473243, 0.30521824829340444, 0.33117050577608703, 0.3315222278856585, 0.33287886492475144, 0.3726740212084118, 0.4169661752561185, 0.388727737878974, 0.405208541196304, 0.42578443911383995, 0.4430189455864624, 0.44731499051242923, 0.4593238715189349, 0.4644741324478555, 0.47572930778674993, 0.4908786248877709, 0.46467512045839715, 0.45902240332087524, 0.49572738244616965, 0.508263865459423, 0.4776135468325906, 0.49336579781741197, 0.46588102339846027, 0.4746490308323511, 0.4776889515668864, 0.4646500123450317, 0.49165743866874756, 0.4868337917360329, 0.4794475671393814, 0.4496263187173563, 0.4669361922394936, 0.45693717626449293, 0.44161205463585756, 0.4272666971139597, 0.40445483804101157, 0.40576125382873596, 0.40837405023172263, 0.4304322061493784, 0.42337259554893286, 0.4326179485657408, 0.4225686736545907, 0.4304070955236941, 0.4664086279175268, 0.45025439839930315, 0.4529425970242669, 0.44839530766392766, 0.45191253880891785, 0.44533027379138945, 0.45711305616166914, 0.4606302873066593, 0.49123034950966116, 0.4593490173170813, 0.4538470342785892, 0.43611006908504674, 0.4349543873963521, 0.4335726045591128, 0.4393006862338309, 0.4235986941851589, 0.43706472507841865, 0.4348036532973223, 0.4399287659157778, 0.43307014835051144, 0.42372431765850443, 0.37950753066031256, 0.38475826926443235, 0.3784021053954486, 0.3736789336256144, 0.35629369305396225, 0.3724730306855513, 0.382823773794761, 0.3765932333991229, 0.3727744988836109, 0.3735282020389034, 0.37501046003902305, 0.3972696064795393, 0.4016159053170181, 0.3949833863879777, 0.3934508694517086, 0.402344500358945, 0.39204397850110373, 0.3879489240979974, 0.3883760132570838, 0.40681642518208805, 0.4144287459026467, 0.4225937817679562, 0.44452631421226635, 0.4367381487669936, 0.4295277688950561, 0.4334721268839136, 0.4553292922787089, 0.47540273398764354, 0.482361829228109, 0.49138108109637224, 0.5075855293536455, 0.5167303695227922, 0.5260259412786498, 0.5342161229421056, 0.5600678675771269, 0.5840353706539887]

# %%
lst_output = []
n_steps = 100
i = 0

while(i < 30):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())

        lst_output.extend(yhat.tolist())
        i += 1

print(lst_output)
# Out:
# [[0.5964759588241577], [0.6090384125709534], [0.6220890879631042], [0.634919285774231], [0.6475783586502075], [0.6600345373153687], [0.6722549200057983], [0.6842193603515625], [0.695907711982727], [0.707300066947937], [0.7183777093887329], [0.7291229963302612], [0.7395198941230774], [0.7495545744895935], [0.759215235710144], [0.7684923410415649], [0.7773787379264832], [0.7858694791793823], [0.7939620614051819], [0.8016563057899475], [0.8089542388916016], [0.8158597946166992], [0.8223787546157837], [0.8285186886787415], [0.8342887163162231], [0.8396995067596436], [0.8447626233100891], [0.8494903445243835], [0.8538959622383118], [0.8579936623573303]]

# %%
datelist_train = df_tsla['Date'].astype(str).tolist()

datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
y_pred_future = scaler.inverse_transform(lst_output)

print(y_pred_future)
# Out:
# [[249.35182914]
#  [254.3521715 ]
#  [259.54684495]
#  [264.6537598 ]
#  [269.6925603 ]
#  [274.65060107]
#  [279.51478592]
#  [284.27709581]
#  [288.92951173]
#  [293.46410952]
#  [297.87343957]
#  [302.15047927]
#  [306.28884662]
#  [310.28303742]
#  [314.12835415]
#  [317.8210008 ]
#  [321.35813038]
#  [324.73777371]
#  [327.95893436]
#  [331.02154115]
#  [333.92640072]
#  [336.67507892]
#  [339.26987708]
#  [341.71380825]
#  [344.01050237]
#  [346.16420619]
#  [348.17952236]
#  [350.06133821]
#  [351.81494442]
#  [353.44598752]]

# %%
y_pred_future = scaler.inverse_transform(lst_output)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Close']).set_index(pd.Series(datelist_future))

plt.figure(figsize=(16,5))

plt.plot(train_data.index[train_size-100:], train_data.Close[train_size-100:])
plt.plot(test_data)

plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('TESLA Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction','30 days'])
plt.show()
