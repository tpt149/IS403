# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import libraries

# %%
import os
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
plt.style.use('dark_background')

from pandas.core.arrays.sparse.array import ScalarIndexer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score

from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM
from keras.callbacks import ModelCheckpoint

# %%
# %cd /content/drive/MyDrive/IS403/Project/Data/
# Out:
# /content/drive/MyDrive/IS403/Project/Data

# %% [markdown]
# # Eval Function

# %%
def eval(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
def train_test_valid(data):
  train_size = int(0.7 * len(data))
  test_size = int(0.2 * len(data))
  val_size = len(data) - train_size - test_size

  train_data = data[:train_size]
  test_data = data[train_size:train_size+test_size]
  valid_data = data[train_size+test_size:]

  return train_data, test_data, valid_data, train_size, test_size, val_size

# %% [markdown]
# # AMAZON

# %% [markdown]
# ## Data

# %%
df_amz = pd.read_csv("AMZN.csv")
df_amz
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2017-12-01   58.602501   58.982498   57.599998   58.117500   58.117500
# 1     2017-12-04   58.692501   58.759998   56.400002   56.697498   56.697498
# 2     2017-12-05   56.412998   57.963501   56.237000   57.078499   57.078499
# 3     2017-12-06   56.899502   57.794498   56.804001   57.617500   57.617500
# 4     2017-12-07   57.829498   58.159500   57.549999   57.989498   57.989498
# ...          ...         ...         ...         ...         ...         ...
# 1384  2023-06-05  123.360001  125.800003  123.029999  125.300003  125.300003
# 1385  2023-06-06  125.070000  127.400002  125.000000  126.610001  126.610001
# 1386  2023-06-07  127.010002  127.370003  120.629997  121.230003  121.230003
# 1387  2023-06-08  123.010002  125.629997  122.260002  124.250000  124.250000
# 1388  2023-06-09  124.080002  125.800003  123.190002  123.430000  123.430000
#
#          Volume
# 0      82142000
# 1     118638000
# 2      81596000
# 3      57066000
# 4      50232000
# ...         ...
# 1384   47950100
# 1385   45695200
# 1386   95663300
# 1387   62159300
# 1388   51330000
#
# [1389 rows x 7 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Check null and na value

# %%
df_amz.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_amz.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Check datatype of each column

# %%
print("Date column data type: ", type(df_amz['Date'][0]))
print("Open column data type: ", type(df_amz['Open'][0]))
print("Close column data type: ", type(df_amz['Close'][0]))
print("High column data type: ", type(df_amz['High'][0]))
print("Low column data type: ", type(df_amz['Low'][0]))
print("Adj Close column data type: ", type(df_amz['Adj Close'][0]))
print("Volume column data type: ", type(df_amz['Low'][0]))
# Out:
# Date column data type:  <class 'str'>
# Open column data type:  <class 'numpy.float64'>
# Close column data type:  <class 'numpy.float64'>
# High column data type:  <class 'numpy.float64'>
# Low column data type:  <class 'numpy.float64'>
# Adj Close column data type:  <class 'numpy.float64'>
# Volume column data type:  <class 'numpy.float64'>

# %% [markdown]
# ### Convert date from string to date format & reset index

# %%
df_amz = df_amz.set_index(pd.DatetimeIndex(df_amz['Date'].values))

df_amz.index = pd.to_datetime(df_amz.index,format='%Y-%m-%d')

close_amz = pd.DataFrame(df_amz, columns=['Date', 'Close'])
close_amz.drop('Date', axis = 1, inplace = True)

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Get the duration of dataset

# %%
print("Starting date: ",df_amz.iloc[0][0])
print("Ending date: ", df_amz.iloc[-1][0])
# Out:
# Starting date:  2017-12-01
# Ending date:  2023-06-09

# %% [markdown]
# ### Visualize the per day closing price of the stock

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(close_amz['Close'])
plt.title('AMAZON closing price')
plt.show()

# %% [markdown]
# ## Train, test, valid

# %%
data_amz = close_amz.values
scaler = MinMaxScaler(feature_range=(0, 1))

sc_train = scaler.fit_transform(data_amz)

train_data, test_data, valid_data, train_size, test_size, val_size = train_test_valid(sc_train)

# %%
x_train, y_train = [], []

for i in range(100, len(train_data)):
    x_train.append(sc_train[i-100:i, 0])
    y_train.append(sc_train[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %% [markdown]
# ## Build & train model

# %%
model = Sequential()

model.add(LSTM(50,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))

model.compile(loss='mean_absolute_error', optimizer='adam')

save_model = '/content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5'

best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.13801, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 10s - loss: 0.1380 - 10s/epoch - 557ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.13801 to 0.03893, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0389 - 3s/epoch - 150ms/step
# Epoch 3/80
#
# Epoch 3: loss did not improve from 0.03893
# 18/18 - 3s - loss: 0.0408 - 3s/epoch - 140ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.03893 to 0.03808, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0381 - 3s/epoch - 164ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.03808 to 0.03365, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 4s - loss: 0.0337 - 4s/epoch - 224ms/step
# Epoch 6/80
#
# Epoch 6: loss did not improve from 0.03365
# 18/18 - 3s - loss: 0.0397 - 3s/epoch - 174ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.03365 to 0.03235, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0323 - 3s/epoch - 142ms/step
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.03235
# 18/18 - 3s - loss: 0.0332 - 3s/epoch - 144ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.03235 to 0.03159, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 4s - loss: 0.0316 - 4s/epoch - 218ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.03159 to 0.03081, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0308 - 3s/epoch - 174ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.03081 to 0.02897, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0290 - 3s/epoch - 144ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.02897 to 0.02844, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0284 - 3s/epoch - 146ms/step
# Epoch 13/80
#
# Epoch 13: loss improved from 0.02844 to 0.02735, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0273 - 3s/epoch - 145ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.02735
# 18/18 - 4s - loss: 0.0300 - 4s/epoch - 245ms/step
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.02735
# 18/18 - 3s - loss: 0.0299 - 3s/epoch - 179ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.02735
# 18/18 - 3s - loss: 0.0304 - 3s/epoch - 145ms/step
# Epoch 17/80
#
# Epoch 17: loss improved from 0.02735 to 0.02653, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0265 - 3s/epoch - 171ms/step
# Epoch 18/80
#
# Epoch 18: loss improved from 0.02653 to 0.02571, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 4s - loss: 0.0257 - 4s/epoch - 210ms/step
# Epoch 19/80
#
# Epoch 19: loss improved from 0.02571 to 0.02438, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0244 - 3s/epoch - 180ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.02438
# 18/18 - 3s - loss: 0.0244 - 3s/epoch - 143ms/step
# Epoch 21/80
#
# Epoch 21: loss improved from 0.02438 to 0.02395, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0239 - 3s/epoch - 146ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.02395
# 18/18 - 3s - loss: 0.0247 - 3s/epoch - 146ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.02395
# 18/18 - 4s - loss: 0.0260 - 4s/epoch - 243ms/step
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.02395
# 18/18 - 3s - loss: 0.0252 - 3s/epoch - 144ms/step
# Epoch 25/80
#
# Epoch 25: loss improved from 0.02395 to 0.02389, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0239 - 3s/epoch - 168ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.02389
# 18/18 - 3s - loss: 0.0240 - 3s/epoch - 145ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.02389
# 18/18 - 3s - loss: 0.0243 - 3s/epoch - 171ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.02389
# 18/18 - 4s - loss: 0.0276 - 4s/epoch - 218ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.02389
# 18/18 - 3s - loss: 0.0292 - 3s/epoch - 142ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.02389
# 18/18 - 3s - loss: 0.0240 - 3s/epoch - 176ms/step
# Epoch 31/80
#
# Epoch 31: loss improved from 0.02389 to 0.02267, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0227 - 3s/epoch - 169ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.02267
# 18/18 - 4s - loss: 0.0229 - 4s/epoch - 240ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.02267
# 18/18 - 3s - loss: 0.0230 - 3s/epoch - 144ms/step
# Epoch 34/80
#
# Epoch 34: loss improved from 0.02267 to 0.02135, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0213 - 3s/epoch - 174ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.02135
# 18/18 - 3s - loss: 0.0227 - 3s/epoch - 144ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.02135
# 18/18 - 3s - loss: 0.0227 - 3s/epoch - 186ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.02135
# 18/18 - 4s - loss: 0.0223 - 4s/epoch - 201ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.02135
# 18/18 - 3s - loss: 0.0216 - 3s/epoch - 147ms/step
# Epoch 39/80
#
# Epoch 39: loss improved from 0.02135 to 0.02064, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0206 - 3s/epoch - 171ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.02064
# 18/18 - 3s - loss: 0.0220 - 3s/epoch - 143ms/step
# Epoch 41/80
#
# Epoch 41: loss improved from 0.02064 to 0.02025, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 5s - loss: 0.0203 - 5s/epoch - 274ms/step
# Epoch 42/80
#
# Epoch 42: loss improved from 0.02025 to 0.02018, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0202 - 3s/epoch - 146ms/step
# Epoch 43/80
#
# Epoch 43: loss improved from 0.02018 to 0.01945, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0194 - 3s/epoch - 152ms/step
# Epoch 44/80
#
# Epoch 44: loss improved from 0.01945 to 0.01892, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0189 - 3s/epoch - 147ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.01892
# 18/18 - 4s - loss: 0.0196 - 4s/epoch - 197ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.01892
# 18/18 - 3s - loss: 0.0219 - 3s/epoch - 192ms/step
# Epoch 47/80
#
# Epoch 47: loss improved from 0.01892 to 0.01864, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0186 - 3s/epoch - 169ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.01864
# 18/18 - 3s - loss: 0.0202 - 3s/epoch - 147ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.01864
# 18/18 - 3s - loss: 0.0242 - 3s/epoch - 145ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.01864
# 18/18 - 4s - loss: 0.0194 - 4s/epoch - 247ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.01864
# 18/18 - 3s - loss: 0.0204 - 3s/epoch - 143ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.01864
# 18/18 - 3s - loss: 0.0215 - 3s/epoch - 142ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.01864
# 18/18 - 3s - loss: 0.0214 - 3s/epoch - 141ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.01864
# 18/18 - 3s - loss: 0.0188 - 3s/epoch - 164ms/step
# Epoch 55/80
#
# Epoch 55: loss improved from 0.01864 to 0.01778, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 4s - loss: 0.0178 - 4s/epoch - 249ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.01778
# 18/18 - 3s - loss: 0.0181 - 3s/epoch - 144ms/step
# Epoch 57/80
#
# Epoch 57: loss improved from 0.01778 to 0.01730, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0173 - 3s/epoch - 149ms/step
# Epoch 58/80
#
# Epoch 58: loss improved from 0.01730 to 0.01685, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0169 - 3s/epoch - 143ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.01685
# 18/18 - 4s - loss: 0.0194 - 4s/epoch - 221ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.01685
# 18/18 - 3s - loss: 0.0210 - 3s/epoch - 164ms/step
# Epoch 61/80
#
# Epoch 61: loss improved from 0.01685 to 0.01619, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0162 - 3s/epoch - 170ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.01619
# 18/18 - 3s - loss: 0.0179 - 3s/epoch - 142ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.01619
# 18/18 - 3s - loss: 0.0177 - 3s/epoch - 159ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.01619
# 18/18 - 5s - loss: 0.0164 - 5s/epoch - 275ms/step
# Epoch 65/80
#
# Epoch 65: loss improved from 0.01619 to 0.01534, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0153 - 3s/epoch - 175ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.01534
# 18/18 - 3s - loss: 0.0157 - 3s/epoch - 144ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.01534
# 18/18 - 3s - loss: 0.0166 - 3s/epoch - 146ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.01534
# 18/18 - 4s - loss: 0.0160 - 4s/epoch - 230ms/step
# Epoch 69/80
#
# Epoch 69: loss improved from 0.01534 to 0.01437, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5
# 18/18 - 3s - loss: 0.0144 - 3s/epoch - 178ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.01437
# 18/18 - 3s - loss: 0.0149 - 3s/epoch - 146ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.01437
# 18/18 - 3s - loss: 0.0159 - 3s/epoch - 141ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.01437
# 18/18 - 3s - loss: 0.0157 - 3s/epoch - 167ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.01437
# 18/18 - 4s - loss: 0.0148 - 4s/epoch - 217ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.01437
# 18/18 - 3s - loss: 0.0191 - 3s/epoch - 149ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.01437
# 18/18 - 3s - loss: 0.0168 - 3s/epoch - 144ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.01437
# 18/18 - 3s - loss: 0.0178 - 3s/epoch - 143ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.01437
# 18/18 - 4s - loss: 0.0172 - 4s/epoch - 212ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.01437
# 18/18 - 3s - loss: 0.0156 - 3s/epoch - 181ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.01437
# 18/18 - 3s - loss: 0.0170 - 3s/epoch - 142ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.01437
# 18/18 - 3s - loss: 0.0147 - 3s/epoch - 142ms/step

# %% [markdown]
# ## Eval

# %%
y_train = scaler.inverse_transform(y_train)

final_model = load_model('/content/drive/MyDrive/IS403/Project/Model/LSTM_AMZ_721.hdf5')

y_train_predict = final_model.predict(x_train)

y_train_predict = scaler.inverse_transform(y_train_predict)
# Out:
# 28/28 [==============================] - 2s 46ms/step

# %%
test = close_amz[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = scaler.transform(test)

x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data_amz[train_size:train_size+test_size]  # True values

y_test_predict = final_model.predict(x_test)

y_test_predict = scaler.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 1s 55ms/step

# %%
val = close_amz[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = scaler.transform(val)

x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

y_val = data_amz[train_size+test_size:]  # True values

y_val_predict = final_model.predict(x_val)

y_val_predict = scaler.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 54ms/step

# %%
train_data = close_amz[:train_size]
test_data = close_amz[train_size:train_size+test_size]
val_data = close_amz[train_size+test_size:]

# %%
eval(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  3.5877022425294736
# MAPE:  2.7653509443136177
# RMSE:  4.581445516720012
#
# ** Validate **
# MAE:  2.1506813192766456
# MAPE:  2.1893916056209686
# RMSE:  2.713761240468439

# %% [markdown]
# ## Predict

# %%
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)
print(x_input.shape)

temp_input = list(x_input)
temp_input = temp_input[0].tolist()
print(temp_input)
# Out:
# (1, 100)
# [0.2984646662272322, 0.2847589766119052, 0.3122473695417426, 0.3143263005293834, 0.3050865276860706, 0.3117083814450792, 0.3274160422476733, 0.3506695056042365, 0.33765683148393943, 0.3575223465619851, 0.3730760415648524, 0.4328267373946353, 0.3595243177492522, 0.3502075312067563, 0.34966855080992276, 0.3338069165077717, 0.3198701857948948, 0.31501931602441324, 0.3298799878324208, 0.33111192982547455, 0.34235373545469394, 0.31917723189850444, 0.311862354944636, 0.2916888389686668, 0.30100562551116283, 0.3012366127099029, 0.28337300722048475, 0.28537497840775183, 0.2889939061851794, 0.2731322179842187, 0.27282421708629534, 0.2941527845534142, 0.2852979647085686, 0.28375802181759135, 0.2866069204008057, 0.27374821978006547, 0.2620445013520054, 0.2751341891714859, 0.29399874945521776, 0.30416252499230056, 0.3337299028085885, 0.325337057361223, 0.3157892836199869, 0.3381188058814196, 0.3234120998731391, 0.32348911357232235, 0.319023196800308, 0.31833024290391754, 0.31217035584255937, 0.33534685939874886, 0.34882156181533597, 0.3587543501536786, 0.3519785228951132, 0.3638362071229001, 0.3418916994585741, 0.34928353621281605, 0.35013051750757307, 0.33280590011481836, 0.31671328631375706, 0.35190150919593, 0.3527484904906869, 0.3545194205804042, 0.3511315339005264, 0.3665311938051973, 0.36275823862940315, 0.3870127106790897, 0.38123783821483814, 0.3532104648881671, 0.3717670781727853, 0.4090342320425989, 0.37538595205140324, 0.34920657641244257, 0.36137226153815283, 0.3615262966363493, 0.3642212217200068, 0.37700297024020346, 0.37831192593244045, 0.3843947992946155, 0.41188318452462314, 0.42720583073011065, 0.41242217262128655, 0.41965997427733204, 0.43659963867161977, 0.4527692661718643, 0.47317383094521315, 0.45854413863611587, 0.4489963648948798, 0.44884233749651326, 0.4623940536122836, 0.4489193511956966, 0.4882654899519606, 0.5002002494775704, 0.4918844177293882, 0.508747006825853, 0.5201427782547994, 0.5282276228042414, 0.5383143846421409, 0.4968893148982362, 0.5201427782547994, 0.5138289176938843]

# %%
lst_output = []
n_steps = 100
i = 0

while(i < 30):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())

        lst_output.extend(yhat.tolist())
        i += 1

print(lst_output)
# Out:
# [[0.514200747013092], [0.5147109627723694], [0.5154621601104736], [0.5163782238960266], [0.5173364281654358], [0.5182633996009827], [0.5191265344619751], [0.5199242234230042], [0.5206763744354248], [0.5214142203330994], [0.5221740007400513], [0.5229901671409607], [0.5238932371139526], [0.5249068737030029], [0.5260482430458069], [0.5273279547691345], [0.5287514328956604], [0.5303196310997009], [0.5320301651954651], [0.5338784456253052], [0.5358582735061646], [0.5379623174667358], [0.540182888507843], [0.5425118803977966], [0.5449410676956177], [0.5474622845649719], [0.5500673651695251], [0.5527482628822327], [0.5554972290992737], [0.5583066344261169]]

# %%
datelist_train = df_amz['Date'].astype(str).tolist()

datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
y_pred_future = scaler.inverse_transform(lst_output)

print(y_pred_future)
# Out:
# [[123.47829059]
#  [123.54455384]
#  [123.64211409]
#  [123.76108604]
#  [123.8855309 ]
#  [124.00591946]
#  [124.11801737]
#  [124.22161563]
#  [124.31929974]
#  [124.41512599]
#  [124.51380095]
#  [124.61979893]
#  [124.73708334]
#  [124.86872736]
#  [125.01696042]
#  [125.18316042]
#  [125.36803179]
#  [125.57169839]
#  [125.79385058]
#  [126.0338923 ]
#  [126.29101848]
#  [126.56427698]
#  [126.8526692 ]
#  [127.15514236]
#  [127.47062819]
#  [127.79806619]
#  [128.13639582]
#  [128.48457204]
#  [128.84158852]
#  [129.20645442]]

# %%
y_pred_future = scaler.inverse_transform(lst_output)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Close']).set_index(pd.Series(datelist_future))

plt.figure(figsize=(16,5))
plt.plot(train_data.index[train_size-100:], train_data.Close[train_size-100:])
plt.plot(test_data)

plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('AMZ Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction','30 days'])
plt.show()

# %% [markdown]
# # NVIDIA

# %% [markdown]
# ## Data

# %%
df_nvda = pd.read_csv("NVDA.csv")
df_nvda
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2017-12-01   49.827499   50.032501   48.117500   49.419998   48.908009
# 1     2017-12-04   50.012501   50.075001   46.125000   46.665001   46.181549
# 2     2017-12-05   45.599998   48.174999   45.145000   46.935001   46.448750
# 3     2017-12-06   46.424999   47.535000   46.209999   47.314999   46.824821
# 4     2017-12-07   47.990002   48.400002   47.529999   47.997501   47.500244
# ...          ...         ...         ...         ...         ...         ...
# 1384  2023-06-05  389.089996  395.649994  387.070007  391.709991  391.669464
# 1385  2023-06-06  388.299988  391.600006  381.480011  386.540009  386.500000
# 1386  2023-06-07  389.149994  394.989990  373.559998  374.750000  374.750000
# 1387  2023-06-08  377.239990  388.640015  375.049988  385.100006  385.100006
# 1388  2023-06-09  390.369995  397.109985  385.670013  387.700012  387.700012
#
#          Volume
# 0      81154800
# 1     124084400
# 2      98148800
# 3      46703200
# 4      54260000
# ...         ...
# 1384   39609400
# 1385   38872900
# 1386   51199800
# 1387   41777200
# 1388   42722000
#
# [1389 rows x 7 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Check null and na value

# %%
df_nvda.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_nvda.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Check datatype of each column

# %%
print("Date column data type: ", type(df_nvda['Date'][0]))
print("Open column data type: ", type(df_nvda['Open'][0]))
print("Close column data type: ", type(df_nvda['Close'][0]))
print("High column data type: ", type(df_nvda['High'][0]))
print("Low column data type: ", type(df_nvda['Low'][0]))
print("Adj Close column data type: ", type(df_nvda['Adj Close'][0]))
print("Volume column data type: ", type(df_nvda['Low'][0]))
# Out:
# Date column data type:  <class 'str'>
# Open column data type:  <class 'numpy.float64'>
# Close column data type:  <class 'numpy.float64'>
# High column data type:  <class 'numpy.float64'>
# Low column data type:  <class 'numpy.float64'>
# Adj Close column data type:  <class 'numpy.float64'>
# Volume column data type:  <class 'numpy.float64'>

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Get the duration of dataset

# %%
print("Starting date: ",df_nvda.iloc[0][0])
print("Ending date: ", df_nvda.iloc[-1][0])
# Out:
# Starting date:  2017-12-01
# Ending date:  2023-06-09

# %% [markdown]
# ### Visualize the per day closing price of the stock

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(df_nvda['Close'])
plt.title('NVIDIA closing price')
plt.show()

# %% [markdown]
# ## Train, test, valid

# %% [markdown]
# ### Convert date from string to date format & reset index

# %%
df_nvda = df_nvda.set_index(pd.DatetimeIndex(df_nvda['Date'].values))

df_nvda.index = pd.to_datetime(df_nvda.index,format='%Y-%m-%d')

close_nvda = pd.DataFrame(df_nvda, columns=['Date', 'Close'])
close_nvda.drop('Date', axis = 1, inplace = True)

# %% [markdown]
# ### Split

# %%
data_nvda = close_nvda.values
scaler = MinMaxScaler(feature_range=(0, 1))

sc_train = scaler.fit_transform(data_nvda)

train_data, test_data, valid_data, train_size, test_size, val_size = train_test_valid(sc_train)

# %%
x_train, y_train = [], []

for i in range(100, len(train_data)):
    x_train.append(sc_train[i-100:i, 0])
    y_train.append(sc_train[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %% [markdown]
# ## Build & train model

# %%
model = Sequential()

model.add(LSTM(50,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))

model.compile(loss='mean_absolute_error', optimizer='adam')

save_model = '/content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5'

best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.05522, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 10s - loss: 0.0552 - 10s/epoch - 547ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.05522 to 0.01757, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0176 - 3s/epoch - 151ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.01757 to 0.01452, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0145 - 3s/epoch - 146ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.01452 to 0.01412, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0141 - 3s/epoch - 145ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.01412 to 0.01365, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 4s - loss: 0.0137 - 4s/epoch - 208ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.01365 to 0.01325, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0132 - 3s/epoch - 179ms/step
# Epoch 7/80
#
# Epoch 7: loss did not improve from 0.01325
# 18/18 - 3s - loss: 0.0137 - 3s/epoch - 147ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.01325 to 0.01293, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0129 - 3s/epoch - 144ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.01293 to 0.01291, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0129 - 3s/epoch - 144ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.01291 to 0.01289, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 4s - loss: 0.0129 - 4s/epoch - 235ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.01289 to 0.01128, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0113 - 3s/epoch - 151ms/step
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.01128
# 18/18 - 3s - loss: 0.0113 - 3s/epoch - 141ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.01128
# 18/18 - 3s - loss: 0.0124 - 3s/epoch - 142ms/step
# Epoch 14/80
#
# Epoch 14: loss improved from 0.01128 to 0.01115, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0112 - 3s/epoch - 187ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.01115 to 0.01054, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 4s - loss: 0.0105 - 4s/epoch - 216ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.01054
# 18/18 - 3s - loss: 0.0109 - 3s/epoch - 144ms/step
# Epoch 17/80
#
# Epoch 17: loss improved from 0.01054 to 0.01049, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0105 - 3s/epoch - 156ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.01049
# 18/18 - 3s - loss: 0.0107 - 3s/epoch - 144ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.01049
# 18/18 - 4s - loss: 0.0117 - 4s/epoch - 208ms/step
# Epoch 20/80
#
# Epoch 20: loss improved from 0.01049 to 0.00982, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 4s - loss: 0.0098 - 4s/epoch - 202ms/step
# Epoch 21/80
#
# Epoch 21: loss improved from 0.00982 to 0.00947, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0095 - 3s/epoch - 147ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.00947
# 18/18 - 3s - loss: 0.0097 - 3s/epoch - 149ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.00947
# 18/18 - 3s - loss: 0.0107 - 3s/epoch - 149ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.00947 to 0.00888, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 5s - loss: 0.0089 - 5s/epoch - 257ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.00888
# 18/18 - 3s - loss: 0.0089 - 3s/epoch - 144ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.00888
# 18/18 - 3s - loss: 0.0097 - 3s/epoch - 151ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.00888
# 18/18 - 3s - loss: 0.0089 - 3s/epoch - 145ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.00888
# 18/18 - 4s - loss: 0.0093 - 4s/epoch - 196ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.00888
# 18/18 - 3s - loss: 0.0107 - 3s/epoch - 186ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.00888
# 18/18 - 3s - loss: 0.0093 - 3s/epoch - 142ms/step
# Epoch 31/80
#
# Epoch 31: loss improved from 0.00888 to 0.00868, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0087 - 3s/epoch - 169ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.00868
# 18/18 - 3s - loss: 0.0087 - 3s/epoch - 141ms/step
# Epoch 33/80
#
# Epoch 33: loss improved from 0.00868 to 0.00810, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 5s - loss: 0.0081 - 5s/epoch - 263ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.00810
# 18/18 - 3s - loss: 0.0088 - 3s/epoch - 142ms/step
# Epoch 35/80
#
# Epoch 35: loss improved from 0.00810 to 0.00810, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0081 - 3s/epoch - 151ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.00810
# 18/18 - 3s - loss: 0.0082 - 3s/epoch - 144ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.00810
# 18/18 - 3s - loss: 0.0085 - 3s/epoch - 176ms/step
# Epoch 38/80
#
# Epoch 38: loss improved from 0.00810 to 0.00754, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 4s - loss: 0.0075 - 4s/epoch - 237ms/step
# Epoch 39/80
#
# Epoch 39: loss improved from 0.00754 to 0.00753, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0075 - 3s/epoch - 151ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.00753
# 18/18 - 3s - loss: 0.0079 - 3s/epoch - 142ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.00753
# 18/18 - 3s - loss: 0.0083 - 3s/epoch - 144ms/step
# Epoch 42/80
#
# Epoch 42: loss improved from 0.00753 to 0.00736, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 5s - loss: 0.0074 - 5s/epoch - 255ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.00736
# 18/18 - 3s - loss: 0.0079 - 3s/epoch - 148ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.00736
# 18/18 - 3s - loss: 0.0080 - 3s/epoch - 142ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.00736
# 18/18 - 3s - loss: 0.0086 - 3s/epoch - 144ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.00736
# 18/18 - 3s - loss: 0.0078 - 3s/epoch - 163ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.00736
# 18/18 - 4s - loss: 0.0080 - 4s/epoch - 222ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.00736
# 18/18 - 3s - loss: 0.0074 - 3s/epoch - 144ms/step
# Epoch 49/80
#
# Epoch 49: loss improved from 0.00736 to 0.00693, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0069 - 3s/epoch - 168ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.00693
# 18/18 - 3s - loss: 0.0070 - 3s/epoch - 143ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.00693
# 18/18 - 4s - loss: 0.0079 - 4s/epoch - 213ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.00693
# 18/18 - 3s - loss: 0.0072 - 3s/epoch - 178ms/step
# Epoch 53/80
#
# Epoch 53: loss improved from 0.00693 to 0.00669, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0067 - 3s/epoch - 170ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.00669
# 18/18 - 3s - loss: 0.0071 - 3s/epoch - 145ms/step
# Epoch 55/80
#
# Epoch 55: loss improved from 0.00669 to 0.00644, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0064 - 3s/epoch - 171ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.00644
# 18/18 - 4s - loss: 0.0068 - 4s/epoch - 224ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.00644
# 18/18 - 3s - loss: 0.0073 - 3s/epoch - 144ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.00644
# 18/18 - 3s - loss: 0.0068 - 3s/epoch - 145ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.00644
# 18/18 - 3s - loss: 0.0068 - 3s/epoch - 144ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.00644
# 18/18 - 3s - loss: 0.0065 - 3s/epoch - 193ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.00644
# 18/18 - 3s - loss: 0.0072 - 3s/epoch - 191ms/step
# Epoch 62/80
#
# Epoch 62: loss improved from 0.00644 to 0.00624, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0062 - 3s/epoch - 171ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.00624
# 18/18 - 3s - loss: 0.0067 - 3s/epoch - 142ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.00624
# 18/18 - 3s - loss: 0.0064 - 3s/epoch - 143ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.00624
# 18/18 - 4s - loss: 0.0077 - 4s/epoch - 244ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.00624
# 18/18 - 3s - loss: 0.0073 - 3s/epoch - 146ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.00624
# 18/18 - 3s - loss: 0.0074 - 3s/epoch - 145ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.00624
# 18/18 - 3s - loss: 0.0067 - 3s/epoch - 142ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.00624
# 18/18 - 3s - loss: 0.0067 - 3s/epoch - 162ms/step
# Epoch 70/80
#
# Epoch 70: loss improved from 0.00624 to 0.00579, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 5s - loss: 0.0058 - 5s/epoch - 252ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.00579
# 18/18 - 3s - loss: 0.0063 - 3s/epoch - 144ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.00579
# 18/18 - 3s - loss: 0.0060 - 3s/epoch - 143ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.00579
# 18/18 - 3s - loss: 0.0061 - 3s/epoch - 145ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.00579
# 18/18 - 4s - loss: 0.0064 - 4s/epoch - 220ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.00579
# 18/18 - 3s - loss: 0.0063 - 3s/epoch - 167ms/step
# Epoch 76/80
#
# Epoch 76: loss improved from 0.00579 to 0.00562, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0056 - 3s/epoch - 171ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.00562
# 18/18 - 3s - loss: 0.0056 - 3s/epoch - 148ms/step
# Epoch 78/80
#
# Epoch 78: loss improved from 0.00562 to 0.00557, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 3s - loss: 0.0056 - 3s/epoch - 158ms/step
# Epoch 79/80
#
# Epoch 79: loss improved from 0.00557 to 0.00545, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5
# 18/18 - 4s - loss: 0.0055 - 4s/epoch - 231ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.00545
# 18/18 - 3s - loss: 0.0055 - 3s/epoch - 143ms/step

# %% [markdown]
# ## Eval

# %%
y_train = scaler.inverse_transform(y_train)

final_model = load_model('/content/drive/MyDrive/IS403/Project/Model/LSTM_NVDA_721.hdf5')

y_train_predict = final_model.predict(x_train)

y_train_predict = scaler.inverse_transform(y_train_predict)
# Out:
# 28/28 [==============================] - 2s 36ms/step

# %%
test = close_nvda[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = scaler.transform(test)

x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data_nvda[train_size:train_size+test_size]  # True values

y_test_predict = final_model.predict(x_test)

y_test_predict = scaler.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 1s 56ms/step

# %%
val = close_nvda[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = scaler.transform(val)

x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

y_val = data_nvda[train_size+test_size:]  # True values

y_val_predict = final_model.predict(x_val)

y_val_predict = scaler.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 55ms/step

# %%
train_data = close_nvda[:train_size]
test_data = close_nvda[train_size:train_size+test_size]
val_data = close_nvda[train_size+test_size:]

# %%
eval(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  7.864407105821298
# MAPE:  3.5825437055993827
# RMSE:  10.83260011264938
#
# ** Validate **
# MAE:  9.444505997600446
# MAPE:  3.6224226064249985
# RMSE:  15.37576734849939

# %% [markdown]
# ## Predict

# %%
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)
print(x_input.shape)

temp_input = list(x_input)
temp_input = temp_input[0].tolist()
print(temp_input)
# Out:
# (1, 100)
# [0.3844696208562417, 0.36789949509528463, 0.3969784073067528, 0.4336383806372873, 0.43558780671960007, 0.4371581809643491, 0.4501272831318277, 0.4653706638342988, 0.4327990509882107, 0.44295229773185796, 0.4810201987743081, 0.5017599055785958, 0.48527104369704244, 0.4849732124183629, 0.5143228562160688, 0.5151892855575873, 0.5187632067510913, 0.4897384560190524, 0.5038988805937163, 0.5359289950694073, 0.5303243812066543, 0.5096929973612253, 0.49306875073382583, 0.4732225323505116, 0.4759029624155099, 0.5546921733914079, 0.5444577060888763, 0.5502788846433726, 0.5425624414859929, 0.528537401657175, 0.5452158097640036, 0.5608111832245837, 0.5517138714347433, 0.5445118675683056, 0.5686901135277839, 0.5485190047863352, 0.5357665079235869, 0.5357936103235613, 0.5654952441718434, 0.5699626564938535, 0.6055125712966062, 0.610494420202026, 0.615232602015728, 0.6233280970106715, 0.6306113674640453, 0.6501868569686545, 0.6390318367506296, 0.6323171264546403, 0.6290410338322833, 0.6445822431059014, 0.65538527327335, 0.6660529566004071, 0.6711431311722178, 0.6572805784892203, 0.6417934900820446, 0.6460172326048045, 0.6606920964704105, 0.6495911944112955, 0.6313424526727047, 0.6304760233311862, 0.6384631953672711, 0.6450695799968692, 0.6630747358697162, 0.670222580964257, 0.6478313172617906, 0.6482374281788092, 0.6461526579636374, 0.6244652985514146, 0.643824139430774, 0.6511345095765897, 0.665294850217747, 0.6967293454565987, 0.6777766182017904, 0.6667298397166502, 0.6602317780459107, 0.6905019720515773, 0.7032545095273126, 0.6875507697873545, 0.6960524623403556, 0.6877403187201623, 0.6812963779158652, 0.6978935654638095, 0.7049331661179332, 0.7310608381597241, 0.7716738251343135, 0.7604646840498464, 0.7580820419430081, 0.7448692699762793, 0.7408079712788204, 0.9423024912940307, 0.9684572630282636, 0.9999999999999999, 0.9383495155554306, 0.9907673873978199, 0.9787729563047444, 0.9745492110744521, 0.960551316966128, 0.9286294848363087, 0.9566524620939701, 0.9636920627480937]

# %%
lst_output = []
n_steps = 100
i = 0

while(i < 30):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())

        lst_output.extend(yhat.tolist())
        i += 1

print(lst_output)
# Out:
# [[0.8836086988449097], [0.7820578813552856], [0.7348626852035522], [0.7338773012161255], [0.733457088470459], [0.7132875919342041], [0.6843836307525635], [0.6634628772735596], [0.6549036502838135], [0.6531014442443848], [0.6520726680755615], [0.6499887704849243], [0.648011326789856], [0.6475621461868286], [0.648897647857666], [0.6513030529022217], [0.6538878679275513], [0.6561044454574585], [0.6577857732772827], [0.6589294672012329], [0.6595081090927124], [0.6594241857528687], [0.6585688591003418], [0.6568907499313354], [0.6544184684753418], [0.6512378454208374], [0.6474580764770508], [0.6431912183761597], [0.6385476589202881], [0.6336376667022705]]

# %%
datelist_train = df_nvda['Date'].astype(str).tolist()

datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
y_pred_future = scaler.inverse_transform(lst_output)

print(y_pred_future)
# Out:
# [[358.12202358]
#  [320.61524617]
#  [303.18417313]
#  [302.82023142]
#  [302.66503005]
#  [295.21562851]
#  [284.54023992]
#  [276.81336914]
#  [273.65210437]
#  [272.98647762]
#  [272.60650945]
#  [271.83684274]
#  [271.10649372]
#  [270.94059336]
#  [271.43384753]
#  [272.32225979]
#  [273.27693533]
#  [274.09560604]
#  [274.71658764]
#  [275.13899953]
#  [275.35271512]
#  [275.32171887]
#  [275.00581254]
#  [274.38601973]
#  [273.47290733]
#  [272.29817606]
#  [270.90215625]
#  [269.32623495]
#  [267.61118277]
#  [265.79772632]]

# %%
y_pred_future = scaler.inverse_transform(lst_output)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Close']).set_index(pd.Series(datelist_future))

plt.figure(figsize=(16,5))

plt.plot(train_data.index[train_size-100:], train_data.Close[train_size-100:])
plt.plot(test_data)

plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('NVIDIA Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction','30 days'])
plt.show()

# %% [markdown]
# # TESLA

# %% [markdown]
# ## Data

# %%
df_tsla = pd.read_csv("TSLA.csv")
df_tsla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2017-12-01   20.362667   20.688000   20.336666   20.435333   20.435333
# 1     2017-12-04   20.433332   20.551332   20.040667   20.346666   20.346666
# 2     2017-12-05   20.133333   20.533333   20.066668   20.246668   20.246668
# 3     2017-12-06   20.006666   20.892668   20.000000   20.884001   20.884001
# 4     2017-12-07   20.799999   21.242001   20.736668   20.749332   20.749332
# ...          ...         ...         ...         ...         ...         ...
# 1384  2023-06-05  217.800003  221.289993  214.520004  217.610001  217.610001
# 1385  2023-06-06  216.139999  221.910004  212.529999  221.309998  221.309998
# 1386  2023-06-07  228.000000  230.830002  223.199997  224.570007  224.570007
# 1387  2023-06-08  224.220001  235.229996  223.009995  234.860001  234.860001
# 1388  2023-06-09  249.070007  252.419998  242.020004  244.399994  244.399994
#
#          Volume
# 0      64393500
# 1      87526500
# 2      69697500
# 3     107929500
# 4      71709000
# ...         ...
# 1384  151143100
# 1385  146911600
# 1386  185710800
# 1387  164489700
# 1388  199882300
#
# [1389 rows x 7 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Check null and na value

# %%
df_tsla.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_tsla.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Check datatype of each column

# %%
print("Date column data type: ", type(df_tsla['Date'][0]))
print("Open column data type: ", type(df_tsla['Open'][0]))
print("Close column data type: ", type(df_tsla['Close'][0]))
print("High column data type: ", type(df_tsla['High'][0]))
print("Low column data type: ", type(df_tsla['Low'][0]))
print("Adj Close column data type: ", type(df_tsla['Adj Close'][0]))
print("Volume column data type: ", type(df_tsla['Low'][0]))
# Out:
# Date column data type:  <class 'str'>
# Open column data type:  <class 'numpy.float64'>
# Close column data type:  <class 'numpy.float64'>
# High column data type:  <class 'numpy.float64'>
# Low column data type:  <class 'numpy.float64'>
# Adj Close column data type:  <class 'numpy.float64'>
# Volume column data type:  <class 'numpy.float64'>

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Get the duration of dataset

# %%
print("Starting date: ",df_tsla.iloc[0][0])
print("Ending date: ", df_tsla.iloc[-1][0])
# Out:
# Starting date:  2017-12-01
# Ending date:  2023-06-09

# %% [markdown]
# ### Visualize the per day closing price of the stock

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(df_tsla['Close'])
plt.title('TESLA closing price')
plt.show()

# %% [markdown]
# ## Train, test, valid

# %% [markdown]
# ### Convert date from string to date format & reset index

# %%
df_tsla = df_tsla.set_index(pd.DatetimeIndex(df_tsla['Date'].values))

df_tsla.index = pd.to_datetime(df_tsla.index,format='%Y-%m-%d')

close_tsla = pd.DataFrame(df_tsla, columns=['Date', 'Close'])
close_tsla.drop('Date', axis = 1, inplace = True)

# %% [markdown]
# ### Split

# %%
data_tsla = close_tsla.values
scaler = MinMaxScaler(feature_range=(0, 1))

sc_train = scaler.fit_transform(data_tsla)

train_data, test_data, valid_data, train_size, test_size, val_size = train_test_valid(sc_train)

# %%
x_train, y_train = [], []

for i in range(100, len(train_data)):
    x_train.append(sc_train[i-100:i, 0])
    y_train.append(sc_train[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %% [markdown]
# ## Build model

# %%
model = Sequential()

model.add(LSTM(50,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))

model.compile(loss='mean_absolute_error', optimizer='adam')

save_model = '/content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5'

best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.07686, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 10s - loss: 0.0769 - 10s/epoch - 530ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.07686 to 0.02431, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0243 - 3s/epoch - 158ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.02431 to 0.02132, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0213 - 4s/epoch - 223ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.02132 to 0.02042, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0204 - 3s/epoch - 192ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.02042 to 0.01905, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0190 - 3s/epoch - 156ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.01905 to 0.01731, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0173 - 3s/epoch - 154ms/step
# Epoch 7/80
#
# Epoch 7: loss did not improve from 0.01731
# 18/18 - 3s - loss: 0.0187 - 3s/epoch - 161ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.01731 to 0.01673, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 5s - loss: 0.0167 - 5s/epoch - 254ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.01673 to 0.01623, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0162 - 3s/epoch - 158ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.01623 to 0.01526, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0153 - 3s/epoch - 154ms/step
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.01526
# 18/18 - 3s - loss: 0.0167 - 3s/epoch - 152ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.01526 to 0.01485, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0149 - 4s/epoch - 218ms/step
# Epoch 13/80
#
# Epoch 13: loss improved from 0.01485 to 0.01446, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0145 - 4s/epoch - 195ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.01446
# 18/18 - 3s - loss: 0.0163 - 3s/epoch - 153ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.01446 to 0.01421, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0142 - 3s/epoch - 154ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.01421
# 18/18 - 3s - loss: 0.0144 - 3s/epoch - 155ms/step
# Epoch 17/80
#
# Epoch 17: loss improved from 0.01421 to 0.01304, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 5s - loss: 0.0130 - 5s/epoch - 257ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.01304
# 18/18 - 3s - loss: 0.0131 - 3s/epoch - 152ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.01304
# 18/18 - 3s - loss: 0.0132 - 3s/epoch - 151ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.01304
# 18/18 - 3s - loss: 0.0140 - 3s/epoch - 151ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.01304
# 18/18 - 4s - loss: 0.0132 - 4s/epoch - 203ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.01304
# 18/18 - 4s - loss: 0.0136 - 4s/epoch - 205ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.01304
# 18/18 - 3s - loss: 0.0132 - 3s/epoch - 152ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.01304 to 0.01229, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0123 - 3s/epoch - 190ms/step
# Epoch 25/80
#
# Epoch 25: loss improved from 0.01229 to 0.01190, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0119 - 4s/epoch - 226ms/step
# Epoch 26/80
#
# Epoch 26: loss improved from 0.01190 to 0.01118, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0112 - 4s/epoch - 223ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.01118
# 18/18 - 3s - loss: 0.0122 - 3s/epoch - 152ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.01118
# 18/18 - 3s - loss: 0.0116 - 3s/epoch - 151ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.01118
# 18/18 - 3s - loss: 0.0112 - 3s/epoch - 152ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.01118
# 18/18 - 4s - loss: 0.0115 - 4s/epoch - 235ms/step
# Epoch 31/80
#
# Epoch 31: loss improved from 0.01118 to 0.01112, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0111 - 4s/epoch - 213ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.01112
# 18/18 - 3s - loss: 0.0124 - 3s/epoch - 150ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.01112
# 18/18 - 3s - loss: 0.0127 - 3s/epoch - 152ms/step
# Epoch 34/80
#
# Epoch 34: loss improved from 0.01112 to 0.01087, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0109 - 4s/epoch - 224ms/step
# Epoch 35/80
#
# Epoch 35: loss improved from 0.01087 to 0.01022, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0102 - 4s/epoch - 196ms/step
# Epoch 36/80
#
# Epoch 36: loss improved from 0.01022 to 0.00976, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0098 - 3s/epoch - 153ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.00976
# 18/18 - 3s - loss: 0.0105 - 3s/epoch - 152ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.00976
# 18/18 - 3s - loss: 0.0102 - 3s/epoch - 157ms/step
# Epoch 39/80
#
# Epoch 39: loss improved from 0.00976 to 0.00968, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 5s - loss: 0.0097 - 5s/epoch - 257ms/step
# Epoch 40/80
#
# Epoch 40: loss improved from 0.00968 to 0.00958, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0096 - 3s/epoch - 156ms/step
# Epoch 41/80
#
# Epoch 41: loss improved from 0.00958 to 0.00910, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0091 - 3s/epoch - 157ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.00910
# 18/18 - 3s - loss: 0.0096 - 3s/epoch - 153ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.00910
# 18/18 - 4s - loss: 0.0099 - 4s/epoch - 209ms/step
# Epoch 44/80
#
# Epoch 44: loss improved from 0.00910 to 0.00874, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0087 - 4s/epoch - 203ms/step
# Epoch 45/80
#
# Epoch 45: loss improved from 0.00874 to 0.00871, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0087 - 3s/epoch - 155ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.00871
# 18/18 - 3s - loss: 0.0087 - 3s/epoch - 152ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.00871
# 18/18 - 3s - loss: 0.0100 - 3s/epoch - 149ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.00871
# 18/18 - 5s - loss: 0.0100 - 5s/epoch - 255ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.00871
# 18/18 - 3s - loss: 0.0091 - 3s/epoch - 154ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.00871
# 18/18 - 3s - loss: 0.0111 - 3s/epoch - 152ms/step
# Epoch 51/80
#
# Epoch 51: loss improved from 0.00871 to 0.00826, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0083 - 3s/epoch - 183ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.00826
# 18/18 - 4s - loss: 0.0084 - 4s/epoch - 212ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.00826
# 18/18 - 4s - loss: 0.0084 - 4s/epoch - 196ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.00826
# 18/18 - 3s - loss: 0.0092 - 3s/epoch - 152ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.00826
# 18/18 - 3s - loss: 0.0102 - 3s/epoch - 153ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.00826
# 18/18 - 3s - loss: 0.0086 - 3s/epoch - 152ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.00826
# 18/18 - 5s - loss: 0.0099 - 5s/epoch - 256ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.00826
# 18/18 - 3s - loss: 0.0090 - 3s/epoch - 185ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.00826
# 18/18 - 3s - loss: 0.0089 - 3s/epoch - 153ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.00826
# 18/18 - 3s - loss: 0.0091 - 3s/epoch - 152ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.00826
# 18/18 - 4s - loss: 0.0086 - 4s/epoch - 217ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.00826
# 18/18 - 3s - loss: 0.0086 - 3s/epoch - 192ms/step
# Epoch 63/80
#
# Epoch 63: loss improved from 0.00826 to 0.00720, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0072 - 3s/epoch - 184ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.00720
# 18/18 - 3s - loss: 0.0081 - 3s/epoch - 151ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.00720
# 18/18 - 3s - loss: 0.0077 - 3s/epoch - 171ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.00720
# 18/18 - 4s - loss: 0.0072 - 4s/epoch - 238ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.00720
# 18/18 - 3s - loss: 0.0088 - 3s/epoch - 148ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.00720
# 18/18 - 3s - loss: 0.0088 - 3s/epoch - 152ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.00720
# 18/18 - 3s - loss: 0.0073 - 3s/epoch - 152ms/step
# Epoch 70/80
#
# Epoch 70: loss improved from 0.00720 to 0.00716, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0072 - 4s/epoch - 246ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.00716
# 18/18 - 3s - loss: 0.0077 - 3s/epoch - 168ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.00716
# 18/18 - 3s - loss: 0.0078 - 3s/epoch - 152ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.00716
# 18/18 - 3s - loss: 0.0078 - 3s/epoch - 152ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.00716
# 18/18 - 3s - loss: 0.0094 - 3s/epoch - 168ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.00716
# 18/18 - 4s - loss: 0.0077 - 4s/epoch - 241ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.00716
# 18/18 - 3s - loss: 0.0082 - 3s/epoch - 152ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.00716
# 18/18 - 3s - loss: 0.0073 - 3s/epoch - 152ms/step
# Epoch 78/80
#
# Epoch 78: loss improved from 0.00716 to 0.00711, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 3s - loss: 0.0071 - 3s/epoch - 183ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.00711
# 18/18 - 4s - loss: 0.0074 - 4s/epoch - 240ms/step
# Epoch 80/80
#
# Epoch 80: loss improved from 0.00711 to 0.00693, saving model to /content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5
# 18/18 - 4s - loss: 0.0069 - 4s/epoch - 212ms/step

# %% [markdown]
# ## Eval

# %%
y_train = scaler.inverse_transform(y_train)

final_model = load_model('/content/drive/MyDrive/IS403/Project/Model/LSTM_TSLA_721.hdf5')

y_train_predict = final_model.predict(x_train)

y_train_predict = scaler.inverse_transform(y_train_predict)
# Out:
# 28/28 [==============================] - 2s 39ms/step

# %%
test = close_tsla[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = scaler.transform(test)

x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data_tsla[train_size:train_size+test_size]  # True values

y_test_predict = final_model.predict(x_test)

y_test_predict = scaler.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 0s 39ms/step

# %%
val = close_tsla[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = scaler.transform(val)

x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

y_val = data_tsla[train_size+test_size:]  # True values

y_val_predict = final_model.predict(x_val)

y_val_predict = scaler.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 35ms/step

# %%
train_data = close_tsla[:train_size]
test_data = close_tsla[train_size:train_size+test_size]
val_data = close_tsla[train_size+test_size:]

# %%
eval(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  11.293502018494754
# MAPE:  3.8257618740704977
# RMSE:  14.347680697308016
#
# ** Validate **
# MAE:  5.1403940892508375
# MAPE:  3.0371876399433395
# RMSE:  6.7009314662171215

# %% [markdown]
# ## Predict

# %%
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)
print(x_input.shape)

temp_input = list(x_input)
temp_input = temp_input[0].tolist()
print(temp_input)
# Out:
# (1, 100)
# [0.2935610919087891, 0.28951625624473243, 0.30521824829340444, 0.33117050577608703, 0.3315222278856585, 0.33287886492475144, 0.3726740212084118, 0.4169661752561185, 0.388727737878974, 0.405208541196304, 0.42578443911383995, 0.4430189455864624, 0.44731499051242923, 0.4593238715189349, 0.4644741324478555, 0.47572930778674993, 0.4908786248877709, 0.46467512045839715, 0.45902240332087524, 0.49572738244616965, 0.508263865459423, 0.4776135468325906, 0.49336579781741197, 0.46588102339846027, 0.4746490308323511, 0.4776889515668864, 0.4646500123450317, 0.49165743866874756, 0.4868337917360329, 0.4794475671393814, 0.4496263187173563, 0.4669361922394936, 0.45693717626449293, 0.44161205463585756, 0.4272666971139597, 0.40445483804101157, 0.40576125382873596, 0.40837405023172263, 0.4304322061493784, 0.42337259554893286, 0.4326179485657408, 0.4225686736545907, 0.4304070955236941, 0.4664086279175268, 0.45025439839930315, 0.4529425970242669, 0.44839530766392766, 0.45191253880891785, 0.44533027379138945, 0.45711305616166914, 0.4606302873066593, 0.49123034950966116, 0.4593490173170813, 0.4538470342785892, 0.43611006908504674, 0.4349543873963521, 0.4335726045591128, 0.4393006862338309, 0.4235986941851589, 0.43706472507841865, 0.4348036532973223, 0.4399287659157778, 0.43307014835051144, 0.42372431765850443, 0.37950753066031256, 0.38475826926443235, 0.3784021053954486, 0.3736789336256144, 0.35629369305396225, 0.3724730306855513, 0.382823773794761, 0.3765932333991229, 0.3727744988836109, 0.3735282020389034, 0.37501046003902305, 0.3972696064795393, 0.4016159053170181, 0.3949833863879777, 0.3934508694517086, 0.402344500358945, 0.39204397850110373, 0.3879489240979974, 0.3883760132570838, 0.40681642518208805, 0.4144287459026467, 0.4225937817679562, 0.44452631421226635, 0.4367381487669936, 0.4295277688950561, 0.4334721268839136, 0.4553292922787089, 0.47540273398764354, 0.482361829228109, 0.49138108109637224, 0.5075855293536455, 0.5167303695227922, 0.5260259412786498, 0.5342161229421056, 0.5600678675771269, 0.5840353706539887]

# %%
lst_output = []
n_steps = 100
i = 0

while(i < 30):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())

        lst_output.extend(yhat.tolist())
        i += 1

print(lst_output)
# Out:
# [[0.5844473242759705], [0.5847688317298889], [0.5863851308822632], [0.5888791680335999], [0.5917683839797974], [0.5944902300834656], [0.5966349840164185], [0.5980129241943359], [0.5986051559448242], [0.5984854698181152], [0.5977547764778137], [0.5965057015419006], [0.5948095917701721], [0.5927159786224365], [0.5902618765830994], [0.5874763131141663], [0.5843862891197205], [0.5810186266899109], [0.5774006247520447], [0.5735608339309692], [0.5695274472236633], [0.56532883644104], [0.5609930157661438], [0.5565476417541504], [0.5520196557044983], [0.5474350452423096], [0.542819619178772], [0.5381978750228882], [0.5335931181907654], [0.5290283560752869]]

# %%
datelist_train = df_tsla['Date'].astype(str).tolist()

datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
y_pred_future = scaler.inverse_transform(lst_output)

print(y_pred_future)
# Out:
# [[244.56396747]
#  [244.69193987]
#  [245.33528943]
#  [246.32801266]
#  [247.47803232]
#  [248.56143232]
#  [249.41512732]
#  [249.96360079]
#  [250.19933193]
#  [250.15169222]
#  [249.86084802]
#  [249.3636679 ]
#  [248.68855062]
#  [247.85521163]
#  [246.87838413]
#  [245.76962215]
#  [244.53967312]
#  [243.19921325]
#  [241.75910858]
#  [240.23072335]
#  [238.62527948]
#  [236.95407004]
#  [235.22824575]
#  [233.458815  ]
#  [231.65650147]
#  [229.83164922]
#  [227.99453118]
#  [226.15489829]
#  [224.32202702]
#  [222.50507519]]

# %%
y_pred_future = scaler.inverse_transform(lst_output)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Close']).set_index(pd.Series(datelist_future))

plt.figure(figsize=(16,5))

plt.plot(train_data.index[train_size-100:], train_data.Close[train_size-100:])
plt.plot(test_data)

plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('TESLA Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction','30 days'])
plt.show()
