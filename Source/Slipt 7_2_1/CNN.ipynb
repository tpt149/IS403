# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import libraries

# %%
import os
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
plt.style.use('dark_background')

from pandas.core.arrays.sparse.array import ScalarIndexer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score

from keras.models import Sequential, load_model
from keras.layers.core import Dense, Activation, Flatten, Dropout
from keras.optimizers import Adam
from keras.layers import Conv1D, Conv2D, MaxPooling1D, MaxPooling2D
from keras.callbacks import ModelCheckpoint

# %%
# %cd /content/drive/MyDrive/IS403/Project/Data/
# Out:
# /content/drive/.shortcut-targets-by-id/1H00NdDTisvXwJcMmLshBS2Qn7PUvkU8H/IS403/Project/Data

# %% [markdown]
# # Eval Function

# %%
def eval(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
def train_test_valid(data):
  train_size = int(0.7 * len(data))
  test_size = int(0.2 * len(data))
  val_size = len(data) - train_size - test_size

  train_data = data[:train_size]
  test_data = data[train_size:train_size+test_size]
  valid_data = data[train_size+test_size:]

  return train_data, test_data, valid_data, train_size, test_size, val_size

# %% [markdown]
# # AMAZON

# %% [markdown]
# ## Data

# %%
df_amz = pd.read_csv("AMZN.csv")
df_amz
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2017-12-01   58.602501   58.982498   57.599998   58.117500   58.117500
# 1     2017-12-04   58.692501   58.759998   56.400002   56.697498   56.697498
# 2     2017-12-05   56.412998   57.963501   56.237000   57.078499   57.078499
# 3     2017-12-06   56.899502   57.794498   56.804001   57.617500   57.617500
# 4     2017-12-07   57.829498   58.159500   57.549999   57.989498   57.989498
# ...          ...         ...         ...         ...         ...         ...
# 1384  2023-06-05  123.360001  125.800003  123.029999  125.300003  125.300003
# 1385  2023-06-06  125.070000  127.400002  125.000000  126.610001  126.610001
# 1386  2023-06-07  127.010002  127.370003  120.629997  121.230003  121.230003
# 1387  2023-06-08  123.010002  125.629997  122.260002  124.250000  124.250000
# 1388  2023-06-09  124.080002  125.800003  123.190002  123.430000  123.430000
#
#          Volume
# 0      82142000
# 1     118638000
# 2      81596000
# 3      57066000
# 4      50232000
# ...         ...
# 1384   47950100
# 1385   45695200
# 1386   95663300
# 1387   62159300
# 1388   51330000
#
# [1389 rows x 7 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Check null and na value

# %%
df_amz.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_amz.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Check datatype of each column

# %%
print("Date column data type: ", type(df_amz['Date'][0]))
print("Open column data type: ", type(df_amz['Open'][0]))
print("Close column data type: ", type(df_amz['Close'][0]))
print("High column data type: ", type(df_amz['High'][0]))
print("Low column data type: ", type(df_amz['Low'][0]))
print("Adj Close column data type: ", type(df_amz['Adj Close'][0]))
print("Volume column data type: ", type(df_amz['Low'][0]))
# Out:
# Date column data type:  <class 'str'>
# Open column data type:  <class 'numpy.float64'>
# Close column data type:  <class 'numpy.float64'>
# High column data type:  <class 'numpy.float64'>
# Low column data type:  <class 'numpy.float64'>
# Adj Close column data type:  <class 'numpy.float64'>
# Volume column data type:  <class 'numpy.float64'>

# %% [markdown]
# ### Convert date from string to date format & reset index

# %%
df_amz = df_amz.set_index(pd.DatetimeIndex(df_amz['Date'].values))

df_amz.index = pd.to_datetime(df_amz.index,format='%Y-%m-%d')

close_amz = pd.DataFrame(df_amz, columns=['Date', 'Close'])
close_amz.drop('Date', axis = 1, inplace = True)

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Get the duration of dataset

# %%
print("Starting date: ",df_amz.iloc[0][0])
print("Ending date: ", df_amz.iloc[-1][0])
# Out:
# Starting date:  2017-12-01
# Ending date:  2023-06-09

# %% [markdown]
# ### Visualize the per day closing price of the stock

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(close_amz['Close'])
plt.title('AMAZON closing price')
plt.show()

# %% [markdown]
# ## Train, test, valid

# %%
data_amz = close_amz.values
scaler = MinMaxScaler(feature_range=(0, 1))

sc_train = scaler.fit_transform(data_amz)

train_data, test_data, valid_data, train_size, test_size, val_size = train_test_valid(sc_train)

# %%
x_train, y_train = [], []

for i in range(100, len(train_data)):
    x_train.append(sc_train[i-100:i, 0])
    y_train.append(sc_train[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %% [markdown]
# ## Build & train model

# %%
model = Sequential()

model.add(Conv1D(8, kernel_size = (1), strides = (1),  padding = 'valid',
               activation = 'relu', input_shape = (100,1)))
model.add(MaxPooling1D(pool_size = (1)))

model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation="relu"))

model.compile(loss='mean_absolute_error', optimizer='adam')

save_model = '/content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5'

best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.16413, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 2s - loss: 0.1641 - 2s/epoch - 88ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.16413 to 0.10749, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.1075 - 157ms/epoch - 9ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.10749 to 0.09662, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0966 - 156ms/epoch - 9ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.09662 to 0.09611, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0961 - 148ms/epoch - 8ms/step
# Epoch 5/80
#
# Epoch 5: loss did not improve from 0.09611
# 18/18 - 0s - loss: 0.0964 - 126ms/epoch - 7ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.09611 to 0.09237, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0924 - 168ms/epoch - 9ms/step
# Epoch 7/80
#
# Epoch 7: loss did not improve from 0.09237
# 18/18 - 0s - loss: 0.0935 - 131ms/epoch - 7ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.09237 to 0.08875, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0887 - 157ms/epoch - 9ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.08875 to 0.08465, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0847 - 129ms/epoch - 7ms/step
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.08465
# 18/18 - 0s - loss: 0.0868 - 71ms/epoch - 4ms/step
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.08465
# 18/18 - 0s - loss: 0.0856 - 73ms/epoch - 4ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.08465 to 0.07835, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0784 - 136ms/epoch - 8ms/step
# Epoch 13/80
#
# Epoch 13: loss improved from 0.07835 to 0.07525, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0752 - 123ms/epoch - 7ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.07525
# 18/18 - 0s - loss: 0.0784 - 70ms/epoch - 4ms/step
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.07525
# 18/18 - 0s - loss: 0.0818 - 69ms/epoch - 4ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.07525
# 18/18 - 0s - loss: 0.0769 - 80ms/epoch - 4ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.07525
# 18/18 - 0s - loss: 0.0755 - 84ms/epoch - 5ms/step
# Epoch 18/80
#
# Epoch 18: loss improved from 0.07525 to 0.07288, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0729 - 112ms/epoch - 6ms/step
# Epoch 19/80
#
# Epoch 19: loss improved from 0.07288 to 0.07276, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0728 - 114ms/epoch - 6ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.07276
# 18/18 - 0s - loss: 0.0740 - 68ms/epoch - 4ms/step
# Epoch 21/80
#
# Epoch 21: loss improved from 0.07276 to 0.07023, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0702 - 115ms/epoch - 6ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.07023
# 18/18 - 0s - loss: 0.0708 - 69ms/epoch - 4ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.07023
# 18/18 - 0s - loss: 0.0719 - 74ms/epoch - 4ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.07023 to 0.06559, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0656 - 110ms/epoch - 6ms/step
# Epoch 25/80
#
# Epoch 25: loss improved from 0.06559 to 0.06439, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0644 - 127ms/epoch - 7ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.06439
# 18/18 - 0s - loss: 0.0646 - 87ms/epoch - 5ms/step
# Epoch 27/80
#
# Epoch 27: loss improved from 0.06439 to 0.06168, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0617 - 116ms/epoch - 6ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.06168
# 18/18 - 0s - loss: 0.0632 - 73ms/epoch - 4ms/step
# Epoch 29/80
#
# Epoch 29: loss improved from 0.06168 to 0.06104, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0610 - 120ms/epoch - 7ms/step
# Epoch 30/80
#
# Epoch 30: loss improved from 0.06104 to 0.05973, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0597 - 117ms/epoch - 6ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.05973
# 18/18 - 0s - loss: 0.0613 - 77ms/epoch - 4ms/step
# Epoch 32/80
#
# Epoch 32: loss improved from 0.05973 to 0.05846, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0585 - 111ms/epoch - 6ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.05846
# 18/18 - 0s - loss: 0.0609 - 77ms/epoch - 4ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.05846
# 18/18 - 0s - loss: 0.0613 - 74ms/epoch - 4ms/step
# Epoch 35/80
#
# Epoch 35: loss improved from 0.05846 to 0.05829, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0583 - 102ms/epoch - 6ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.05829
# 18/18 - 0s - loss: 0.0638 - 88ms/epoch - 5ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.05829
# 18/18 - 0s - loss: 0.0604 - 69ms/epoch - 4ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.05829
# 18/18 - 0s - loss: 0.0589 - 79ms/epoch - 4ms/step
# Epoch 39/80
#
# Epoch 39: loss improved from 0.05829 to 0.05703, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0570 - 104ms/epoch - 6ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.05703
# 18/18 - 0s - loss: 0.0582 - 71ms/epoch - 4ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.05703
# 18/18 - 0s - loss: 0.0578 - 73ms/epoch - 4ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.05703
# 18/18 - 0s - loss: 0.0642 - 76ms/epoch - 4ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.05703
# 18/18 - 0s - loss: 0.0602 - 74ms/epoch - 4ms/step
# Epoch 44/80
#
# Epoch 44: loss improved from 0.05703 to 0.05552, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0555 - 108ms/epoch - 6ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.05552
# 18/18 - 0s - loss: 0.0571 - 81ms/epoch - 5ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.05552
# 18/18 - 0s - loss: 0.0610 - 68ms/epoch - 4ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.05552
# 18/18 - 0s - loss: 0.0582 - 65ms/epoch - 4ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.05552
# 18/18 - 0s - loss: 0.0585 - 83ms/epoch - 5ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.05552
# 18/18 - 0s - loss: 0.0559 - 79ms/epoch - 4ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.05552
# 18/18 - 0s - loss: 0.0561 - 74ms/epoch - 4ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.05552
# 18/18 - 0s - loss: 0.0566 - 79ms/epoch - 4ms/step
# Epoch 52/80
#
# Epoch 52: loss improved from 0.05552 to 0.05550, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0555 - 113ms/epoch - 6ms/step
# Epoch 53/80
#
# Epoch 53: loss improved from 0.05550 to 0.05356, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0536 - 104ms/epoch - 6ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.05356
# 18/18 - 0s - loss: 0.0575 - 71ms/epoch - 4ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.05356
# 18/18 - 0s - loss: 0.0570 - 80ms/epoch - 4ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.05356
# 18/18 - 0s - loss: 0.0536 - 73ms/epoch - 4ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.05356
# 18/18 - 0s - loss: 0.0562 - 72ms/epoch - 4ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.05356
# 18/18 - 0s - loss: 0.0561 - 72ms/epoch - 4ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.05356
# 18/18 - 0s - loss: 0.0567 - 67ms/epoch - 4ms/step
# Epoch 60/80
#
# Epoch 60: loss improved from 0.05356 to 0.05294, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0529 - 124ms/epoch - 7ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.05294
# 18/18 - 0s - loss: 0.0540 - 192ms/epoch - 11ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.05294
# 18/18 - 0s - loss: 0.0536 - 181ms/epoch - 10ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.05294
# 18/18 - 0s - loss: 0.0563 - 178ms/epoch - 10ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.05294
# 18/18 - 0s - loss: 0.0551 - 172ms/epoch - 10ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.05294
# 18/18 - 0s - loss: 0.0557 - 140ms/epoch - 8ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.05294
# 18/18 - 0s - loss: 0.0555 - 158ms/epoch - 9ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.05294
# 18/18 - 0s - loss: 0.0579 - 133ms/epoch - 7ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.05294
# 18/18 - 0s - loss: 0.0580 - 74ms/epoch - 4ms/step
# Epoch 69/80
#
# Epoch 69: loss improved from 0.05294 to 0.05149, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5
# 18/18 - 0s - loss: 0.0515 - 109ms/epoch - 6ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.05149
# 18/18 - 0s - loss: 0.0549 - 80ms/epoch - 4ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.05149
# 18/18 - 0s - loss: 0.0556 - 74ms/epoch - 4ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.05149
# 18/18 - 0s - loss: 0.0520 - 69ms/epoch - 4ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.05149
# 18/18 - 0s - loss: 0.0523 - 77ms/epoch - 4ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.05149
# 18/18 - 0s - loss: 0.0542 - 71ms/epoch - 4ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.05149
# 18/18 - 0s - loss: 0.0552 - 82ms/epoch - 5ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.05149
# 18/18 - 0s - loss: 0.0556 - 73ms/epoch - 4ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.05149
# 18/18 - 0s - loss: 0.0538 - 85ms/epoch - 5ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.05149
# 18/18 - 0s - loss: 0.0526 - 72ms/epoch - 4ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.05149
# 18/18 - 0s - loss: 0.0538 - 76ms/epoch - 4ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.05149
# 18/18 - 0s - loss: 0.0547 - 78ms/epoch - 4ms/step

# %% [markdown]
# ## Eval

# %%
y_train = scaler.inverse_transform(y_train)

final_model = load_model('/content/drive/MyDrive/IS403/Project/Model/CNN_AMZ_721.hdf5')

y_train_predict = final_model.predict(x_train)

y_train_predict = scaler.inverse_transform(y_train_predict)
# Out:
# 28/28 [==============================] - 0s 2ms/step

# %%
test = close_amz[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = scaler.transform(test)

x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data_amz[train_size:train_size+test_size]  # True values

y_test_predict = final_model.predict(x_test)

y_test_predict = scaler.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
val = close_amz[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = scaler.transform(val)

x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

y_val = data_amz[train_size+test_size:]  # True values

y_val_predict = final_model.predict(x_val)

y_val_predict = scaler.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
train_data = close_amz[:train_size]
test_data = close_amz[train_size:train_size+test_size]
val_data = close_amz[train_size+test_size:]

# %%
eval(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  6.013666521225251
# MAPE:  4.604242589302856
# RMSE:  7.40729710357318
#
# ** Validate **
# MAE:  2.9784576142961776
# MAPE:  2.986518291283363
# RMSE:  3.781900525822515

# %% [markdown]
# ## Predict

# %%
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)
print(x_input.shape)

temp_input = list(x_input)
temp_input = temp_input[0].tolist()
print(temp_input)
# Out:
# (1, 100)
# [0.2984646662272322, 0.2847589766119052, 0.3122473695417426, 0.3143263005293834, 0.3050865276860706, 0.3117083814450792, 0.3274160422476733, 0.3506695056042365, 0.33765683148393943, 0.3575223465619851, 0.3730760415648524, 0.4328267373946353, 0.3595243177492522, 0.3502075312067563, 0.34966855080992276, 0.3338069165077717, 0.3198701857948948, 0.31501931602441324, 0.3298799878324208, 0.33111192982547455, 0.34235373545469394, 0.31917723189850444, 0.311862354944636, 0.2916888389686668, 0.30100562551116283, 0.3012366127099029, 0.28337300722048475, 0.28537497840775183, 0.2889939061851794, 0.2731322179842187, 0.27282421708629534, 0.2941527845534142, 0.2852979647085686, 0.28375802181759135, 0.2866069204008057, 0.27374821978006547, 0.2620445013520054, 0.2751341891714859, 0.29399874945521776, 0.30416252499230056, 0.3337299028085885, 0.325337057361223, 0.3157892836199869, 0.3381188058814196, 0.3234120998731391, 0.32348911357232235, 0.319023196800308, 0.31833024290391754, 0.31217035584255937, 0.33534685939874886, 0.34882156181533597, 0.3587543501536786, 0.3519785228951132, 0.3638362071229001, 0.3418916994585741, 0.34928353621281605, 0.35013051750757307, 0.33280590011481836, 0.31671328631375706, 0.35190150919593, 0.3527484904906869, 0.3545194205804042, 0.3511315339005264, 0.3665311938051973, 0.36275823862940315, 0.3870127106790897, 0.38123783821483814, 0.3532104648881671, 0.3717670781727853, 0.4090342320425989, 0.37538595205140324, 0.34920657641244257, 0.36137226153815283, 0.3615262966363493, 0.3642212217200068, 0.37700297024020346, 0.37831192593244045, 0.3843947992946155, 0.41188318452462314, 0.42720583073011065, 0.41242217262128655, 0.41965997427733204, 0.43659963867161977, 0.4527692661718643, 0.47317383094521315, 0.45854413863611587, 0.4489963648948798, 0.44884233749651326, 0.4623940536122836, 0.4489193511956966, 0.4882654899519606, 0.5002002494775704, 0.4918844177293882, 0.508747006825853, 0.5201427782547994, 0.5282276228042414, 0.5383143846421409, 0.4968893148982362, 0.5201427782547994, 0.5138289176938843]

# %%
lst_output = []
n_steps = 100
i = 0

while(i < 30):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())

        lst_output.extend(yhat.tolist())
        i += 1

print(lst_output)
# Out:
# [[0.5203951597213745], [0.5221474170684814], [0.5268112421035767], [0.531735897064209], [0.5298354625701904], [0.5312659740447998], [0.5389283895492554], [0.5389645099639893], [0.54305100440979], [0.5495120286941528], [0.5506643056869507], [0.5571640729904175], [0.5609810948371887], [0.563579797744751], [0.5639804601669312], [0.5685020089149475], [0.5726165771484375], [0.5786932110786438], [0.5857739448547363], [0.5871703624725342], [0.5899832248687744], [0.5973381996154785], [0.5966185331344604], [0.5953661799430847], [0.601585865020752], [0.6029316782951355], [0.6067718863487244], [0.6141334772109985], [0.6176866292953491], [0.6191462278366089]]

# %%
datelist_train = df_amz['Date'].astype(str).tolist()

datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
y_pred_future = scaler.inverse_transform(lst_output)

print(y_pred_future)
# Out:
# [[124.28277754]
#  [124.51034845]
#  [125.11605339]
#  [125.7556331 ]
#  [125.50881797]
#  [125.69460278]
#  [126.68974366]
#  [126.69443472]
#  [127.22516001]
#  [128.0642726 ]
#  [128.21392227]
#  [129.05806654]
#  [129.55379461]
#  [129.89129595]
#  [129.94333118]
#  [130.53055827]
#  [131.06492958]
#  [131.85412025]
#  [132.77371637]
#  [132.95507331]
#  [133.32038818]
#  [134.2756008 ]
#  [134.18213556]
#  [134.0194887 ]
#  [134.82725784]
#  [135.00204265]
#  [135.50078198]
#  [136.45685386]
#  [136.91831237]
#  [137.10787481]]

# %%
y_pred_future = scaler.inverse_transform(lst_output)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Close']).set_index(pd.Series(datelist_future))

plt.figure(figsize=(16,5))
plt.plot(train_data.index[train_size-100:], train_data.Close[train_size-100:])
plt.plot(test_data)

plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('AMZ Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction','30 days'])
plt.show()

# %% [markdown]
# # NVIDIA

# %% [markdown]
# ## Data

# %%
df_nvda = pd.read_csv("NVDA.csv")
df_nvda
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2017-12-01   49.827499   50.032501   48.117500   49.419998   48.908009
# 1     2017-12-04   50.012501   50.075001   46.125000   46.665001   46.181549
# 2     2017-12-05   45.599998   48.174999   45.145000   46.935001   46.448750
# 3     2017-12-06   46.424999   47.535000   46.209999   47.314999   46.824821
# 4     2017-12-07   47.990002   48.400002   47.529999   47.997501   47.500244
# ...          ...         ...         ...         ...         ...         ...
# 1384  2023-06-05  389.089996  395.649994  387.070007  391.709991  391.669464
# 1385  2023-06-06  388.299988  391.600006  381.480011  386.540009  386.500000
# 1386  2023-06-07  389.149994  394.989990  373.559998  374.750000  374.750000
# 1387  2023-06-08  377.239990  388.640015  375.049988  385.100006  385.100006
# 1388  2023-06-09  390.369995  397.109985  385.670013  387.700012  387.700012
#
#          Volume
# 0      81154800
# 1     124084400
# 2      98148800
# 3      46703200
# 4      54260000
# ...         ...
# 1384   39609400
# 1385   38872900
# 1386   51199800
# 1387   41777200
# 1388   42722000
#
# [1389 rows x 7 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Check null and na value

# %%
df_nvda.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_nvda.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Check datatype of each column

# %%
print("Date column data type: ", type(df_nvda['Date'][0]))
print("Open column data type: ", type(df_nvda['Open'][0]))
print("Close column data type: ", type(df_nvda['Close'][0]))
print("High column data type: ", type(df_nvda['High'][0]))
print("Low column data type: ", type(df_nvda['Low'][0]))
print("Adj Close column data type: ", type(df_nvda['Adj Close'][0]))
print("Volume column data type: ", type(df_nvda['Low'][0]))
# Out:
# Date column data type:  <class 'str'>
# Open column data type:  <class 'numpy.float64'>
# Close column data type:  <class 'numpy.float64'>
# High column data type:  <class 'numpy.float64'>
# Low column data type:  <class 'numpy.float64'>
# Adj Close column data type:  <class 'numpy.float64'>
# Volume column data type:  <class 'numpy.float64'>

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Get the duration of dataset

# %%
print("Starting date: ",df_nvda.iloc[0][0])
print("Ending date: ", df_nvda.iloc[-1][0])
# Out:
# Starting date:  2017-12-01
# Ending date:  2023-06-09

# %% [markdown]
# ### Visualize the per day closing price of the stock

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(df_nvda['Close'])
plt.title('NVIDIA closing price')
plt.show()

# %% [markdown]
# ## Train, test, valid

# %% [markdown]
# ### Convert date from string to date format & reset index

# %%
df_nvda = df_nvda.set_index(pd.DatetimeIndex(df_nvda['Date'].values))

df_nvda.index = pd.to_datetime(df_nvda.index,format='%Y-%m-%d')

close_nvda = pd.DataFrame(df_nvda, columns=['Date', 'Close'])
close_nvda.drop('Date', axis = 1, inplace = True)

# %% [markdown]
# ### Split

# %%
data_nvda = close_nvda.values
scaler = MinMaxScaler(feature_range=(0, 1))

sc_train = scaler.fit_transform(data_nvda)

train_data, test_data, valid_data, train_size, test_size, val_size = train_test_valid(sc_train)

# %%
x_train, y_train = [], []

for i in range(100, len(train_data)):
    x_train.append(sc_train[i-100:i, 0])
    y_train.append(sc_train[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %% [markdown]
# ## Build & train model

# %%
model = Sequential()

model.add(Conv1D(8, kernel_size = (1), strides = (1),  padding = 'valid',
               activation = 'relu', input_shape = (100,1)))
model.add(MaxPooling1D(pool_size = (1)))

model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation="relu"))

model.compile(loss='mean_absolute_error', optimizer='adam')

save_model = '/content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5'

best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.05034, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 1s - loss: 0.0503 - 860ms/epoch - 48ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.05034 to 0.03601, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0360 - 131ms/epoch - 7ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.03601 to 0.03232, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0323 - 118ms/epoch - 7ms/step
# Epoch 4/80
#
# Epoch 4: loss did not improve from 0.03232
# 18/18 - 0s - loss: 0.0328 - 78ms/epoch - 4ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.03232 to 0.02982, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0298 - 118ms/epoch - 7ms/step
# Epoch 6/80
#
# Epoch 6: loss did not improve from 0.02982
# 18/18 - 0s - loss: 0.0319 - 71ms/epoch - 4ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.02982 to 0.02944, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0294 - 107ms/epoch - 6ms/step
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.02944
# 18/18 - 0s - loss: 0.0295 - 73ms/epoch - 4ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.02944 to 0.02831, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0283 - 103ms/epoch - 6ms/step
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.02831
# 18/18 - 0s - loss: 0.0285 - 66ms/epoch - 4ms/step
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.02831
# 18/18 - 0s - loss: 0.0319 - 74ms/epoch - 4ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.02831 to 0.02774, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0277 - 111ms/epoch - 6ms/step
# Epoch 13/80
#
# Epoch 13: loss improved from 0.02774 to 0.02687, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0269 - 110ms/epoch - 6ms/step
# Epoch 14/80
#
# Epoch 14: loss improved from 0.02687 to 0.02670, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0267 - 114ms/epoch - 6ms/step
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.02670
# 18/18 - 0s - loss: 0.0280 - 82ms/epoch - 5ms/step
# Epoch 16/80
#
# Epoch 16: loss improved from 0.02670 to 0.02632, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0263 - 110ms/epoch - 6ms/step
# Epoch 17/80
#
# Epoch 17: loss improved from 0.02632 to 0.02610, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0261 - 102ms/epoch - 6ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.02610
# 18/18 - 0s - loss: 0.0269 - 84ms/epoch - 5ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.02610
# 18/18 - 0s - loss: 0.0270 - 74ms/epoch - 4ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.02610
# 18/18 - 0s - loss: 0.0264 - 73ms/epoch - 4ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.02610
# 18/18 - 0s - loss: 0.0265 - 81ms/epoch - 5ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.02610
# 18/18 - 0s - loss: 0.0281 - 77ms/epoch - 4ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.02610
# 18/18 - 0s - loss: 0.0276 - 78ms/epoch - 4ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.02610 to 0.02575, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0257 - 125ms/epoch - 7ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.02575
# 18/18 - 0s - loss: 0.0267 - 79ms/epoch - 4ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.02575
# 18/18 - 0s - loss: 0.0264 - 84ms/epoch - 5ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.02575
# 18/18 - 0s - loss: 0.0267 - 72ms/epoch - 4ms/step
# Epoch 28/80
#
# Epoch 28: loss improved from 0.02575 to 0.02466, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0247 - 105ms/epoch - 6ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.02466
# 18/18 - 0s - loss: 0.0256 - 74ms/epoch - 4ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.02466
# 18/18 - 0s - loss: 0.0253 - 77ms/epoch - 4ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.02466
# 18/18 - 0s - loss: 0.0278 - 77ms/epoch - 4ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.02466
# 18/18 - 0s - loss: 0.0262 - 75ms/epoch - 4ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.02466
# 18/18 - 0s - loss: 0.0265 - 71ms/epoch - 4ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.02466
# 18/18 - 0s - loss: 0.0264 - 95ms/epoch - 5ms/step
# Epoch 35/80
#
# Epoch 35: loss improved from 0.02466 to 0.02460, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0246 - 105ms/epoch - 6ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.02460
# 18/18 - 0s - loss: 0.0272 - 82ms/epoch - 5ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.02460
# 18/18 - 0s - loss: 0.0252 - 77ms/epoch - 4ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.02460
# 18/18 - 0s - loss: 0.0252 - 78ms/epoch - 4ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.02460
# 18/18 - 0s - loss: 0.0267 - 74ms/epoch - 4ms/step
# Epoch 40/80
#
# Epoch 40: loss improved from 0.02460 to 0.02363, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0236 - 108ms/epoch - 6ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.02363
# 18/18 - 0s - loss: 0.0248 - 85ms/epoch - 5ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.02363
# 18/18 - 0s - loss: 0.0256 - 81ms/epoch - 5ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.02363
# 18/18 - 0s - loss: 0.0262 - 82ms/epoch - 5ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.02363
# 18/18 - 0s - loss: 0.0267 - 94ms/epoch - 5ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.02363
# 18/18 - 0s - loss: 0.0250 - 97ms/epoch - 5ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.02363
# 18/18 - 0s - loss: 0.0246 - 77ms/epoch - 4ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.02363
# 18/18 - 0s - loss: 0.0251 - 78ms/epoch - 4ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.02363
# 18/18 - 0s - loss: 0.0242 - 79ms/epoch - 4ms/step
# Epoch 49/80
#
# Epoch 49: loss improved from 0.02363 to 0.02329, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0233 - 118ms/epoch - 7ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0239 - 71ms/epoch - 4ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0246 - 77ms/epoch - 4ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0265 - 91ms/epoch - 5ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0253 - 72ms/epoch - 4ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0234 - 71ms/epoch - 4ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0249 - 79ms/epoch - 4ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0268 - 78ms/epoch - 4ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0252 - 77ms/epoch - 4ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0259 - 83ms/epoch - 5ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0267 - 70ms/epoch - 4ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0238 - 63ms/epoch - 4ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0245 - 72ms/epoch - 4ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.02329
# 18/18 - 0s - loss: 0.0255 - 73ms/epoch - 4ms/step
# Epoch 63/80
#
# Epoch 63: loss improved from 0.02329 to 0.02167, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5
# 18/18 - 0s - loss: 0.0217 - 109ms/epoch - 6ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0251 - 75ms/epoch - 4ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0275 - 70ms/epoch - 4ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0250 - 80ms/epoch - 4ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0244 - 72ms/epoch - 4ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0255 - 70ms/epoch - 4ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0242 - 79ms/epoch - 4ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0250 - 71ms/epoch - 4ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0259 - 74ms/epoch - 4ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0247 - 65ms/epoch - 4ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0246 - 71ms/epoch - 4ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0256 - 70ms/epoch - 4ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0239 - 88ms/epoch - 5ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0243 - 70ms/epoch - 4ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0250 - 72ms/epoch - 4ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0243 - 69ms/epoch - 4ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0243 - 90ms/epoch - 5ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.02167
# 18/18 - 0s - loss: 0.0241 - 64ms/epoch - 4ms/step

# %% [markdown]
# ## Eval

# %%
y_train = scaler.inverse_transform(y_train)

final_model = load_model('/content/drive/MyDrive/IS403/Project/Model/CNN_NVDA_721.hdf5')

y_train_predict = final_model.predict(x_train)

y_train_predict = scaler.inverse_transform(y_train_predict)
# Out:
# 28/28 [==============================] - 0s 2ms/step

# %%
test = close_nvda[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = scaler.transform(test)

x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data_nvda[train_size:train_size+test_size]  # True values

y_test_predict = final_model.predict(x_test)

y_test_predict = scaler.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
val = close_nvda[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = scaler.transform(val)

x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

y_val = data_nvda[train_size+test_size:]  # True values

y_val_predict = final_model.predict(x_val)

y_val_predict = scaler.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
train_data = close_nvda[:train_size]
test_data = close_nvda[train_size:train_size+test_size]
val_data = close_nvda[train_size+test_size:]

# %%
eval(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  13.067848020969652
# MAPE:  6.36629595958718
# RMSE:  16.118760923824354
#
# ** Validate **
# MAE:  13.061534993345422
# MAPE:  5.371450834347501
# RMSE:  18.216337066990274

# %% [markdown]
# ## Predict

# %%
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)
print(x_input.shape)

temp_input = list(x_input)
temp_input = temp_input[0].tolist()
print(temp_input)
# Out:
# (1, 100)
# [0.3844696208562417, 0.36789949509528463, 0.3969784073067528, 0.4336383806372873, 0.43558780671960007, 0.4371581809643491, 0.4501272831318277, 0.4653706638342988, 0.4327990509882107, 0.44295229773185796, 0.4810201987743081, 0.5017599055785958, 0.48527104369704244, 0.4849732124183629, 0.5143228562160688, 0.5151892855575873, 0.5187632067510913, 0.4897384560190524, 0.5038988805937163, 0.5359289950694073, 0.5303243812066543, 0.5096929973612253, 0.49306875073382583, 0.4732225323505116, 0.4759029624155099, 0.5546921733914079, 0.5444577060888763, 0.5502788846433726, 0.5425624414859929, 0.528537401657175, 0.5452158097640036, 0.5608111832245837, 0.5517138714347433, 0.5445118675683056, 0.5686901135277839, 0.5485190047863352, 0.5357665079235869, 0.5357936103235613, 0.5654952441718434, 0.5699626564938535, 0.6055125712966062, 0.610494420202026, 0.615232602015728, 0.6233280970106715, 0.6306113674640453, 0.6501868569686545, 0.6390318367506296, 0.6323171264546403, 0.6290410338322833, 0.6445822431059014, 0.65538527327335, 0.6660529566004071, 0.6711431311722178, 0.6572805784892203, 0.6417934900820446, 0.6460172326048045, 0.6606920964704105, 0.6495911944112955, 0.6313424526727047, 0.6304760233311862, 0.6384631953672711, 0.6450695799968692, 0.6630747358697162, 0.670222580964257, 0.6478313172617906, 0.6482374281788092, 0.6461526579636374, 0.6244652985514146, 0.643824139430774, 0.6511345095765897, 0.665294850217747, 0.6967293454565987, 0.6777766182017904, 0.6667298397166502, 0.6602317780459107, 0.6905019720515773, 0.7032545095273126, 0.6875507697873545, 0.6960524623403556, 0.6877403187201623, 0.6812963779158652, 0.6978935654638095, 0.7049331661179332, 0.7310608381597241, 0.7716738251343135, 0.7604646840498464, 0.7580820419430081, 0.7448692699762793, 0.7408079712788204, 0.9423024912940307, 0.9684572630282636, 0.9999999999999999, 0.9383495155554306, 0.9907673873978199, 0.9787729563047444, 0.9745492110744521, 0.960551316966128, 0.9286294848363087, 0.9566524620939701, 0.9636920627480937]

# %%
lst_output = []
n_steps = 100
i = 0

while(i < 30):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())

        lst_output.extend(yhat.tolist())
        i += 1

print(lst_output)
# Out:
# [[0.9633260369300842], [0.9587941765785217], [0.9617151618003845], [0.9647457599639893], [0.9687690138816833], [0.9665790796279907], [0.9704809784889221], [0.9711781144142151], [0.9751680493354797], [0.9789965748786926], [0.9831435680389404], [0.985858142375946], [0.9858310222625732], [0.9818743467330933], [0.988623857498169], [0.9997591376304626], [1.0038585662841797], [1.0096391439437866], [1.0107492208480835], [1.0154389142990112], [1.0179529190063477], [1.027270793914795], [1.030792236328125], [1.043220043182373], [1.0528168678283691], [1.0638377666473389], [1.073695182800293], [1.0863217115402222], [1.0952337980270386], [1.1090776920318604]]

# %%
datelist_train = df_nvda['Date'].astype(str).tolist()

datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
y_pred_future = scaler.inverse_transform(lst_output)

print(y_pred_future)
# Out:
# [[387.56482403]
#  [385.8910268 ]
#  [386.96986343]
#  [388.08918451]
#  [389.57513306]
#  [388.76630277]
#  [390.20743004]
#  [390.46491021]
#  [391.93855271]
#  [393.35258028]
#  [394.88423067]
#  [395.88683152]
#  [395.87681497]
#  [394.41545649]
#  [396.9083207 ]
#  [401.0210249 ]
#  [402.53510781]
#  [404.67010628]
#  [405.08010207]
#  [406.81219338]
#  [407.74071584]
#  [411.18217962]
#  [412.4827891 ]
#  [417.0728751 ]
#  [420.61736617]
#  [424.68782478]
#  [428.32856271]
#  [432.99204465]
#  [436.28363453]
#  [441.39673814]]

# %%
y_pred_future = scaler.inverse_transform(lst_output)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Close']).set_index(pd.Series(datelist_future))

plt.figure(figsize=(16,5))

plt.plot(train_data.index[train_size-100:], train_data.Close[train_size-100:])
plt.plot(test_data)

plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('NVIDIA Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction','30 days'])
plt.show()

# %% [markdown]
# # TESLA

# %% [markdown]
# ## Data

# %%
df_tsla = pd.read_csv("TSLA.csv")
df_tsla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2017-12-01   20.362667   20.688000   20.336666   20.435333   20.435333
# 1     2017-12-04   20.433332   20.551332   20.040667   20.346666   20.346666
# 2     2017-12-05   20.133333   20.533333   20.066668   20.246668   20.246668
# 3     2017-12-06   20.006666   20.892668   20.000000   20.884001   20.884001
# 4     2017-12-07   20.799999   21.242001   20.736668   20.749332   20.749332
# ...          ...         ...         ...         ...         ...         ...
# 1384  2023-06-05  217.800003  221.289993  214.520004  217.610001  217.610001
# 1385  2023-06-06  216.139999  221.910004  212.529999  221.309998  221.309998
# 1386  2023-06-07  228.000000  230.830002  223.199997  224.570007  224.570007
# 1387  2023-06-08  224.220001  235.229996  223.009995  234.860001  234.860001
# 1388  2023-06-09  249.070007  252.419998  242.020004  244.399994  244.399994
#
#          Volume
# 0      64393500
# 1      87526500
# 2      69697500
# 3     107929500
# 4      71709000
# ...         ...
# 1384  151143100
# 1385  146911600
# 1386  185710800
# 1387  164489700
# 1388  199882300
#
# [1389 rows x 7 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Check null and na value

# %%
df_tsla.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_tsla.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ### Check datatype of each column

# %%
print("Date column data type: ", type(df_tsla['Date'][0]))
print("Open column data type: ", type(df_tsla['Open'][0]))
print("Close column data type: ", type(df_tsla['Close'][0]))
print("High column data type: ", type(df_tsla['High'][0]))
print("Low column data type: ", type(df_tsla['Low'][0]))
print("Adj Close column data type: ", type(df_tsla['Adj Close'][0]))
print("Volume column data type: ", type(df_tsla['Low'][0]))
# Out:
# Date column data type:  <class 'str'>
# Open column data type:  <class 'numpy.float64'>
# Close column data type:  <class 'numpy.float64'>
# High column data type:  <class 'numpy.float64'>
# Low column data type:  <class 'numpy.float64'>
# Adj Close column data type:  <class 'numpy.float64'>
# Volume column data type:  <class 'numpy.float64'>

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Get the duration of dataset

# %%
print("Starting date: ",df_tsla.iloc[0][0])
print("Ending date: ", df_tsla.iloc[-1][0])
# Out:
# Starting date:  2017-12-01
# Ending date:  2023-06-09

# %% [markdown]
# ### Visualize the per day closing price of the stock

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(df_tsla['Close'])
plt.title('TESLA closing price')
plt.show()

# %% [markdown]
# ## Train, test, valid

# %% [markdown]
# ### Convert date from string to date format & reset index

# %%
df_tsla = df_tsla.set_index(pd.DatetimeIndex(df_tsla['Date'].values))

df_tsla.index = pd.to_datetime(df_tsla.index,format='%Y-%m-%d')

close_tsla = pd.DataFrame(df_tsla, columns=['Date', 'Close'])
close_tsla.drop('Date', axis = 1, inplace = True)

# %% [markdown]
# ### Split

# %%
data_tsla = close_tsla.values
scaler = MinMaxScaler(feature_range=(0, 1))

sc_train = scaler.fit_transform(data_tsla)

train_data, test_data, valid_data, train_size, test_size, val_size = train_test_valid(sc_train)

# %%
x_train, y_train = [], []

for i in range(100, len(train_data)):
    x_train.append(sc_train[i-100:i, 0])
    y_train.append(sc_train[i, 0])

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %% [markdown]
# ## Build model

# %%
model = Sequential()

model.add(Conv1D(8, kernel_size = (1), strides = (1),  padding = 'valid',
               activation = 'relu', input_shape = (100,1)))
model.add(MaxPooling1D(pool_size = (1)))

model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation="relu"))

model.compile(loss='mean_absolute_error', optimizer='adam')

save_model = '/content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5'

best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.08254, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 2s - loss: 0.0825 - 2s/epoch - 99ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.08254 to 0.05459, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0546 - 147ms/epoch - 8ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.05459 to 0.04789, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0479 - 140ms/epoch - 8ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.04789 to 0.04399, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0440 - 153ms/epoch - 9ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.04399 to 0.04020, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0402 - 150ms/epoch - 8ms/step
# Epoch 6/80
#
# Epoch 6: loss did not improve from 0.04020
# 18/18 - 0s - loss: 0.0411 - 106ms/epoch - 6ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.04020 to 0.03912, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0391 - 137ms/epoch - 8ms/step
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.03912
# 18/18 - 0s - loss: 0.0400 - 108ms/epoch - 6ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.03912 to 0.03862, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0386 - 146ms/epoch - 8ms/step
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.03862
# 18/18 - 0s - loss: 0.0389 - 103ms/epoch - 6ms/step
# Epoch 11/80
#
# Epoch 11: loss improved from 0.03862 to 0.03789, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0379 - 140ms/epoch - 8ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.03789 to 0.03731, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0373 - 156ms/epoch - 9ms/step
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.03731
# 18/18 - 0s - loss: 0.0403 - 99ms/epoch - 5ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.03731
# 18/18 - 0s - loss: 0.0384 - 105ms/epoch - 6ms/step
# Epoch 15/80
#
# Epoch 15: loss improved from 0.03731 to 0.03557, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0356 - 143ms/epoch - 8ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.03557
# 18/18 - 0s - loss: 0.0389 - 109ms/epoch - 6ms/step
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.03557
# 18/18 - 0s - loss: 0.0364 - 114ms/epoch - 6ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.03557
# 18/18 - 0s - loss: 0.0381 - 100ms/epoch - 6ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.03557
# 18/18 - 0s - loss: 0.0382 - 109ms/epoch - 6ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.03557
# 18/18 - 0s - loss: 0.0380 - 108ms/epoch - 6ms/step
# Epoch 21/80
#
# Epoch 21: loss improved from 0.03557 to 0.03404, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0340 - 149ms/epoch - 8ms/step
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.03404
# 18/18 - 0s - loss: 0.0354 - 115ms/epoch - 6ms/step
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.03404
# 18/18 - 0s - loss: 0.0372 - 103ms/epoch - 6ms/step
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.03404
# 18/18 - 0s - loss: 0.0386 - 101ms/epoch - 6ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.03404
# 18/18 - 0s - loss: 0.0357 - 72ms/epoch - 4ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.03404
# 18/18 - 0s - loss: 0.0350 - 74ms/epoch - 4ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.03404
# 18/18 - 0s - loss: 0.0367 - 71ms/epoch - 4ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.03404
# 18/18 - 0s - loss: 0.0351 - 67ms/epoch - 4ms/step
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.03404
# 18/18 - 0s - loss: 0.0356 - 72ms/epoch - 4ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.03404
# 18/18 - 0s - loss: 0.0350 - 79ms/epoch - 4ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.03404
# 18/18 - 0s - loss: 0.0381 - 80ms/epoch - 4ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.03404
# 18/18 - 0s - loss: 0.0344 - 87ms/epoch - 5ms/step
# Epoch 33/80
#
# Epoch 33: loss improved from 0.03404 to 0.03383, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0338 - 109ms/epoch - 6ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.03383
# 18/18 - 0s - loss: 0.0364 - 70ms/epoch - 4ms/step
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.03383
# 18/18 - 0s - loss: 0.0373 - 76ms/epoch - 4ms/step
# Epoch 36/80
#
# Epoch 36: loss improved from 0.03383 to 0.03340, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0334 - 103ms/epoch - 6ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.03340
# 18/18 - 0s - loss: 0.0358 - 72ms/epoch - 4ms/step
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.03340
# 18/18 - 0s - loss: 0.0348 - 72ms/epoch - 4ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.03340
# 18/18 - 0s - loss: 0.0372 - 75ms/epoch - 4ms/step
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.03340
# 18/18 - 0s - loss: 0.0350 - 66ms/epoch - 4ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.03340
# 18/18 - 0s - loss: 0.0372 - 67ms/epoch - 4ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.03340
# 18/18 - 0s - loss: 0.0349 - 69ms/epoch - 4ms/step
# Epoch 43/80
#
# Epoch 43: loss improved from 0.03340 to 0.03296, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0330 - 110ms/epoch - 6ms/step
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0356 - 86ms/epoch - 5ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0349 - 72ms/epoch - 4ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0371 - 69ms/epoch - 4ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0335 - 72ms/epoch - 4ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0349 - 79ms/epoch - 4ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0346 - 71ms/epoch - 4ms/step
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0346 - 70ms/epoch - 4ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0332 - 73ms/epoch - 4ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0339 - 69ms/epoch - 4ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0344 - 75ms/epoch - 4ms/step
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0342 - 69ms/epoch - 4ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0332 - 77ms/epoch - 4ms/step
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0343 - 72ms/epoch - 4ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0343 - 85ms/epoch - 5ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0339 - 73ms/epoch - 4ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0344 - 70ms/epoch - 4ms/step
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0334 - 66ms/epoch - 4ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0338 - 69ms/epoch - 4ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0349 - 76ms/epoch - 4ms/step
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0355 - 69ms/epoch - 4ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0363 - 70ms/epoch - 4ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0356 - 67ms/epoch - 4ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0353 - 70ms/epoch - 4ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0353 - 80ms/epoch - 4ms/step
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0348 - 69ms/epoch - 4ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0332 - 71ms/epoch - 4ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0349 - 69ms/epoch - 4ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.03296
# 18/18 - 0s - loss: 0.0330 - 81ms/epoch - 5ms/step
# Epoch 72/80
#
# Epoch 72: loss improved from 0.03296 to 0.03257, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0326 - 129ms/epoch - 7ms/step
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.03257
# 18/18 - 0s - loss: 0.0326 - 72ms/epoch - 4ms/step
# Epoch 74/80
#
# Epoch 74: loss improved from 0.03257 to 0.03254, saving model to /content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5
# 18/18 - 0s - loss: 0.0325 - 102ms/epoch - 6ms/step
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.03254
# 18/18 - 0s - loss: 0.0335 - 82ms/epoch - 5ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.03254
# 18/18 - 0s - loss: 0.0359 - 70ms/epoch - 4ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.03254
# 18/18 - 0s - loss: 0.0378 - 68ms/epoch - 4ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.03254
# 18/18 - 0s - loss: 0.0363 - 66ms/epoch - 4ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.03254
# 18/18 - 0s - loss: 0.0357 - 75ms/epoch - 4ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.03254
# 18/18 - 0s - loss: 0.0338 - 70ms/epoch - 4ms/step

# %% [markdown]
# ## Eval

# %%
y_train = scaler.inverse_transform(y_train)

final_model = load_model('/content/drive/MyDrive/IS403/Project/Model/CNN_TSLA_721.hdf5')

y_train_predict = final_model.predict(x_train)

y_train_predict = scaler.inverse_transform(y_train_predict)
# Out:
# 28/28 [==============================] - 0s 2ms/step

# %%
test = close_tsla[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = scaler.transform(test)

x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

y_test = data_tsla[train_size:train_size+test_size]  # True values

y_test_predict = final_model.predict(x_test)

y_test_predict = scaler.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
val = close_tsla[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = scaler.transform(val)

x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

y_val = data_tsla[train_size+test_size:]  # True values

y_val_predict = final_model.predict(x_val)

y_val_predict = scaler.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 [==============================] - 0s 5ms/step

# %%
train_data = close_tsla[:train_size]
test_data = close_tsla[train_size:train_size+test_size]
val_data = close_tsla[train_size+test_size:]

# %%
eval(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  17.438851244912712
# MAPE:  6.031097780163761
# RMSE:  21.736156418341075
#
# ** Validate **
# MAE:  12.252012839610071
# MAPE:  7.416631616652469
# RMSE:  14.91297999496719

# %% [markdown]
# ## Predict

# %%
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)
print(x_input.shape)

temp_input = list(x_input)
temp_input = temp_input[0].tolist()
print(temp_input)
# Out:
# (1, 100)
# [0.2935610919087891, 0.28951625624473243, 0.30521824829340444, 0.33117050577608703, 0.3315222278856585, 0.33287886492475144, 0.3726740212084118, 0.4169661752561185, 0.388727737878974, 0.405208541196304, 0.42578443911383995, 0.4430189455864624, 0.44731499051242923, 0.4593238715189349, 0.4644741324478555, 0.47572930778674993, 0.4908786248877709, 0.46467512045839715, 0.45902240332087524, 0.49572738244616965, 0.508263865459423, 0.4776135468325906, 0.49336579781741197, 0.46588102339846027, 0.4746490308323511, 0.4776889515668864, 0.4646500123450317, 0.49165743866874756, 0.4868337917360329, 0.4794475671393814, 0.4496263187173563, 0.4669361922394936, 0.45693717626449293, 0.44161205463585756, 0.4272666971139597, 0.40445483804101157, 0.40576125382873596, 0.40837405023172263, 0.4304322061493784, 0.42337259554893286, 0.4326179485657408, 0.4225686736545907, 0.4304070955236941, 0.4664086279175268, 0.45025439839930315, 0.4529425970242669, 0.44839530766392766, 0.45191253880891785, 0.44533027379138945, 0.45711305616166914, 0.4606302873066593, 0.49123034950966116, 0.4593490173170813, 0.4538470342785892, 0.43611006908504674, 0.4349543873963521, 0.4335726045591128, 0.4393006862338309, 0.4235986941851589, 0.43706472507841865, 0.4348036532973223, 0.4399287659157778, 0.43307014835051144, 0.42372431765850443, 0.37950753066031256, 0.38475826926443235, 0.3784021053954486, 0.3736789336256144, 0.35629369305396225, 0.3724730306855513, 0.382823773794761, 0.3765932333991229, 0.3727744988836109, 0.3735282020389034, 0.37501046003902305, 0.3972696064795393, 0.4016159053170181, 0.3949833863879777, 0.3934508694517086, 0.402344500358945, 0.39204397850110373, 0.3879489240979974, 0.3883760132570838, 0.40681642518208805, 0.4144287459026467, 0.4225937817679562, 0.44452631421226635, 0.4367381487669936, 0.4295277688950561, 0.4334721268839136, 0.4553292922787089, 0.47540273398764354, 0.482361829228109, 0.49138108109637224, 0.5075855293536455, 0.5167303695227922, 0.5260259412786498, 0.5342161229421056, 0.5600678675771269, 0.5840353706539887]

# %%
lst_output = []
n_steps = 100
i = 0

while(i < 30):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)

        temp_input.extend(yhat[0].tolist())

        lst_output.extend(yhat.tolist())
        i += 1

print(lst_output)
# Out:
# [[0.4895763695240021], [0.4842793047428131], [0.4814314842224121], [0.4769314229488373], [0.4714089035987854], [0.46704453229904175], [0.46257731318473816], [0.4568087160587311], [0.45085203647613525], [0.44466933608055115], [0.43783262372016907], [0.4306161105632782], [0.422526091337204], [0.4150276482105255], [0.4075474739074707], [0.40047913789749146], [0.3935087323188782], [0.38469377160072327], [0.37928831577301025], [0.37143611907958984], [0.36106500029563904], [0.3524932563304901], [0.34404414892196655], [0.3355236351490021], [0.325680673122406], [0.315596342086792], [0.3053494393825531], [0.2968667149543762], [0.28691932559013367], [0.2758443057537079]]

# %%
datelist_train = df_tsla['Date'].astype(str).tolist()

datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]

datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
y_pred_future = scaler.inverse_transform(lst_output)

print(y_pred_future)
# Out:
# [[206.80165901]
#  [204.6932224 ]
#  [203.55967971]
#  [201.76848132]
#  [199.57030507]
#  [197.83311653]
#  [196.05499059]
#  [193.75886587]
#  [191.38787706]
#  [188.92692323]
#  [186.20564735]
#  [183.33319607]
#  [180.11305559]
#  [177.12838528]
#  [174.15098666]
#  [171.33751561]
#  [168.56302466]
#  [165.05432944]
#  [162.902749  ]
#  [159.77727109]
#  [155.64916478]
#  [152.23727923]
#  [148.87420777]
#  [145.48271382]
#  [141.56483432]
#  [137.55088063]
#  [133.47221713]
#  [130.09576479]
#  [126.13631918]
#  [121.72803304]]

# %%
y_pred_future = scaler.inverse_transform(lst_output)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['Close']).set_index(pd.Series(datelist_future))

plt.figure(figsize=(16,5))

plt.plot(train_data.index[train_size-100:], train_data.Close[train_size-100:])
plt.plot(test_data)

plt.plot(test_data.index, y_test_predict)
plt.plot(val_data)
plt.plot(val_data.index, y_val_predict)

plt.plot(PREDICTIONS_FUTURE)
plt.xlabel('Date')
plt.ylabel('Close')
plt.title('TESLA Prediction')
plt.legend(['Train','Test','Test Prediction','Validate', 'Validate Prediction','30 days'])
plt.show()
